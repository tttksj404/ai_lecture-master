# %% [markdown]
# # 단축키
#
# ## 명령모드 단축키
#
# - `a`: 위에 셀 생성
# - `b`: 아래에 셀 생성
# - `d d`: 해당 셀 삭제
# - `z`: 셀 복구
#
# - `m`: 마크다운 셀로 변환
# - `y`: code 셀로 변환

# %% [markdown]
# ## 실행 단축키
#
# - `ctrl + Enter`: 실행 후 현재 셀 유지
# - `shift + Enter`: 실행 후 아래 셀로 이동

# %%
print("test")
# Out:
# test
