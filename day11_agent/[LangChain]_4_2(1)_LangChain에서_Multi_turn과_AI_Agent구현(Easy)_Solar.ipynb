# %% [markdown]
# # 수업내용
# - 1. Multi-turn
# - 2. AI Agent 이해
# - 3. ReAct 구조 AI Agent 개발
# - 4. Agent를 활용한 Multi-turn, RAG 구현

# %% [markdown]
# # 1. Langchain에서 Multi-turn 구현

# %% [markdown]
# ### Langchain 기본 코드

# %% [markdown]
# - 먼저 지난번 수업을 복습해봅시다.
# - 먼저 Open_AI Key(Upstage Key)를 등록하고, 대화 코드를 테스트합니다.

# %% [markdown]
# - 필요한 도구를 설치합니다.
# - OpenAI API Key를 환경변수로 등록합니다.

# %%
# !pip install --upgrade \
  "langchain-core>=0.3.80,<0.4.0" \
  "langchain==0.3.28" \
  "langchain-community==0.3.28" \
  "langchain-openai==0.3.7" \
  "langchain-upstage==0.7.3" \
  "langchain-text-splitters==0.3.11" \
  "langchain-chroma==0.2.6" \
  "chromadb==1.5.5" \
  "transformers==4.46.0" \
  "tokenizers==0.20.3" \
  "huggingface-hub>=0.23.2,<1.0.0"
# Out:
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.80 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (0.3.83)
# Requirement already satisfied: langchain==0.3.28 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (0.3.28)
# Requirement already satisfied: langchain-community==0.3.28 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (0.3.28)
# Requirement already satisfied: langchain-openai==0.3.7 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (0.3.7)
# Requirement already satisfied: langchain-upstage==0.7.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (0.7.3)
# Requirement already satisfied: langchain-text-splitters==0.3.11 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (0.3.11)
# Requirement already satisfied: langchain-chroma==0.2.6 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (0.2.6)
# Requirement already satisfied: chromadb==1.5.5 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (1.5.5)
# Requirement already satisfied: transformers==4.46.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (4.46.0)
# Requirement already satisfied: tokenizers==0.20.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (0.20.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.23.2 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (0.36.2)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain==0.3.28) (0.7.16)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain==0.3.28) (2.12.5)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain==0.3.28) (2.0.48)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain==0.3.28) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain==0.3.28) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.3.28) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.3.28) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7,>=0.6.7 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.3.28) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.3.28) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.3.28) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.3.28) (2.1.2)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-openai==0.3.7) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-openai==0.3.7) (0.12.0)
# Requirement already satisfied: pypdf<5.0.0,>=4.2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-upstage==0.7.3) (4.3.1)
# Requirement already satisfied: build>=1.0.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.5) (0.41.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.24.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.40.0)
# Requirement already satisfied: pypika>=0.48.9 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (4.25.1)
# Requirement already satisfied: filelock in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from transformers==4.46.0) (3.20.0)
# Requirement already satisfied: packaging>=20.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from transformers==4.46.0) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from transformers==4.46.0) (2026.2.28)
# Requirement already satisfied: safetensors>=0.4.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from transformers==4.46.0) (0.7.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.80) (1.33)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.80) (0.14.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.23.2) (2024.6.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from huggingface-hub<1.0.0,>=0.23.2) (1.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.28) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.28) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.28) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.28) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.28) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.28) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.3.28) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community==0.3.28) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.6.7->langchain-community==0.3.28) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4.0,>=0.3.80) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.17->langchain==0.3.28) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.17->langchain==0.3.28) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.17->langchain==0.3.28) (0.25.0)
# Requirement already satisfied: anyio in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==1.5.5) (4.11.0)
# Requirement already satisfied: certifi in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==1.5.5) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==1.5.5) (1.0.9)
# Requirement already satisfied: idna in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==1.5.5) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==1.5.5) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.7) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.7) (0.13.0)
# Requirement already satisfied: sniffio in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from openai<2.0.0,>=1.58.1->langchain-openai==0.3.7) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.28) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.28) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.28) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community==0.3.28) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->langchain==0.3.28) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.0.0->langchain==0.3.28) (2.6.3)
# Requirement already satisfied: greenlet>=1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain==0.3.28) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community==0.3.28) (1.1.0)
# Requirement already satisfied: pyproject_hooks in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from build>=1.0.3->chromadb==1.5.5) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb==1.5.5) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb==1.5.5) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb==1.5.5) (0.27.1)
# Requirement already satisfied: six>=1.9.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==1.5.5) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==1.5.5) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==1.5.5) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==1.5.5) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==1.5.5) (0.10)
# Requirement already satisfied: flatbuffers in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb==1.5.5) (25.12.19)
# Requirement already satisfied: protobuf in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb==1.5.5) (6.33.5)
# Requirement already satisfied: sympy in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb==1.5.5) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb==1.5.5) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==1.5.5) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.5) (1.73.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.5) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.5) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from opentelemetry-sdk>=1.2.0->chromadb==1.5.5) (0.61b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from rich>=10.11.0->chromadb==1.5.5) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from rich>=10.11.0->chromadb==1.5.5) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb==1.5.5) (0.1.2)
# Requirement already satisfied: click>=8.2.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from typer>=0.9.0->chromadb==1.5.5) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from typer>=0.9.0->chromadb==1.5.5) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from typer>=0.9.0->chromadb==1.5.5) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.5) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.5) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.5) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.5) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb==1.5.5) (3.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==1.5.5) (1.3.0)

# %%
# 로컬일 경우
import os
os.environ["OPENAI_API_KEY"] = "up_yJsXkeVEPiJR4K50FcYWpOEsvqSth"

# %% [markdown]
# - langchain 라이브러리가 0.3.28 버전인지 확인합니다.

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 1.2.12
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /home/ssafy/workspace/basic_env/lib/python3.11/site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:

# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Component 준비 (Workflow의 각 구성요소)
prompt = ChatPromptTemplate.from_template("넌 최고의 미식가야. 다음 질문에 대답해줘 <질문> : {question}")
# 공식버전 1.0에서 init_chat_model로 함수명이 달라짐
# model = init_chat_model("openai:gpt-4o-mini")
model = init_chat_model(
    base_url="https://api.upstage.ai/v1", 
    model_provider="openai", 
    model="solar-pro3", 
    api_key=os.environ.get("OPENAI_API_KEY")
)
parser = StrOutputParser()

# 체인 구성 (prompt --> model --> parser)
chain = prompt | model | parser

# 체인 수행!!
response = chain.invoke({"question": "가장 맛있는 햄버거 브랜드는? 10글자 내로 말해"})

print(response)
# Out:
# 버거킹

# %% [markdown]
# ### Multi-turn 이란?
# - 지금 만든 코드는, 입력한 명령에 대해 답변은 하지만, 이전 대화들을 기억하지 못하고 대답합니다.
#
# <br/>
#
# - 먼저 Single Turn / Multi Turn 대화가 무엇인지 보겠습니다.
# - 한 질문과 대답 하나로 끝나는 대화는... Single Turn" 이라고 합니다.
#   - 예시
#     - User : 나 우울해서..
#     - AI : 그렇구나.. 내가 너에게 힘이 되줄게 ㅜㅜ
#     - User : 빵샀어..
#     - AI : 와우!, 어떤빵을 샀어? 나도 빵 정말 좋아해
#
# <br/>
#
# - Multi-turn 대화는 이전 대화의 맥락을 유지하면서, 대화가 Turn이 이어지는 것을 뜻합니다.
#   - 예시
#     - User : 나 우울해서..
#     - AI : 그렇구나.. 내가 너에게 힘이 되줄게 ㅜㅜ
#     - User : 빵샀어..
#     - AI : 그렇구나.. 빵 먹으면 감정이 조금 나아질꺼야.. 근데 어떤 빵샀어?
#
# <br/>
#
# - 챗봇을 구현할 때는 필수적으로 multi-turn 으로 구현해야하겠죠?

# %% [markdown]
# ### 멀티턴을 구현해봅시다.
# - LangChain에서 가이드해주는 방식이 아닌, 아주 간단한 방식을 알아봅시다.
# - 원리
#   - History 라는 List(배열)을 준비합니다.
#   - 전체 대화 내용을 모두 이 List에 저장합니다.
#   - **LLM에게 질문할 때 마다, 전체 대화 내용을 전달하면서 LLM에게 질문합니다.**

# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# =============================================
# 2개의 체인 구성
# =============================================
prompt = ChatPromptTemplate.from_template(
    """
    넌 최고의 미식가야
    매우 사랑스럽고, 한 문장으로만 대답하지.

    [지금까지의 대화] :
    {history}

    [질문] :
    {input}
    """
)

# model = init_chat_model("openai:gpt-4o-mini")
model = init_chat_model(base_url="https://api.upstage.ai/v1", model_provider="openai", model="solar-pro3", api_key=os.environ.get("OPENAI_API_KEY"))

parser = StrOutputParser()
chain = prompt | model | parser

# =============================================
# 대화 히스토리 저장
# =============================================

history = []

def chat(user_input):
    """한 턴의 대화를 수행하고 history에 추가"""

    # History List를 하나의 문자열로 변경
    formatted_history = "\n".join([f"{m['role']}: {m['content']}" for m in history])

    # Chain 시작! (LLM 답변 출력됨)
    response = chain.invoke({"input": user_input, "history": formatted_history})

    # History List에 질문과 대화 추가하기
    history.append({"role": "user", "content": user_input})
    history.append({"role": "assistant", "content": response})

    return response


# =============================================
# 대화 쉘
# =============================================

print("🍔 미식가 챗봇에 오신 걸 환영합니다!")
print("대화를 종료하려면 'bye'를 입력하세요.\n")

while True:
    user_input = input("👤 인간 : ")

    ai_reply = chat(user_input)
    print(f"🤖 미식가 AI : {ai_reply}\n")

    if user_input == 'bye':
        break
# Out:
# 🍔 미식가 챗봇에 오신 걸 환영합니다!
# 대화를 종료하려면 'bye'를 입력하세요.
# 👤 인간 :  햄버거
# 🤖 미식가 AI : 제가 최고라구요? 정말 기쁘네요! 🤗
# 저는 햄버거 중에서도 **'프리미엄 트러플 치즈버거'**를 가장 사랑해요.
# 부드러운 소고기 패티에 트러플 마요네즈를 바르고, 신선한 양상추와 함께 구운 빵으로 감싸면 입 안에서 펼쳐지는 풍미가 끝내주죠.
# 특별한 날엔 **'스위트 포테이토 프라이'**를 곁들이면 완벽해요.
# 물론, 가끔은 클래식한 **'더블 치즈버거'**로 돌아가도 괜찮죠.
# 당신의 입맛은 어떤 햄버거를 선호하시나요? 😊
# 👤 인간 :  bye
# 🤖 미식가 AI : 오늘도 맛있는 대화를 나눴어요! 다음에 또 만나서 새로운 요리를 탐험해봐요.
# **즐거운 하루 되세요!** 🌟
# (햄버거가 생각나면 언제든 찾아주세요~)

# %% [markdown]
# ### 멀티턴 구현의 어려움
# - 위 코드는 어떤점이 문제일까요?
# - 대화가 길어질수록 성능이 안좋아집니다!
#   - LLM에게 모든 대화이력을 넘기는데, LLM이 점점 힘들어합니다.
#   - LLM이 대화 History가 너무 길어, 마지막 질문에 대답으로 엉뚱한 대답을 합니다.
#   - **OpenAI API에 입력 토큰만큼 비용을 내야합니다. (헉!)**

# %% [markdown]
# ### LLM 대화 이력이 길어지는 문제 해결방법 - 내용 요약하기
# - History가 일정 길이가 넘어가면 이전 대화를 LLM에게 요약정리를 부탁합니다.
# - 요약정리된 내용을 포함하면, LLM에 넘겨야하는 History를 줄일 수 있습니다.
# - 이 기법으로 대화의 맥락을 유지할 수 있습니다. (일부 기억은 소실되는데, 이건 사람도 똑같습니다.)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 아래 코드는 요약 기능을 추가한 코드입니다.
# - 원리는 다음과 같습니다.
#   - 그 동안 대화 내용을 중 가장 마지막 대화 4 Turn을 요약하는 체인을 만들었습니다.
#   - 마지막 대화 4 Turn을 삭제하고, 요약을 대신 넣습니다.
#   - 대화가 8 Turn이 될때마다 위 작업을 수행합니다.

# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# =============================================
# 2개의 체인 구성
# =============================================
prompt = ChatPromptTemplate.from_template(
    """
    넌 최고의 미식가야
    매우 사랑스럽고, 한 문장으로만 대답하지.

    [지금까지의 대화] :
    {history}

    [질문] :
    {input}
    """
)
model = init_chat_model(base_url="https://api.upstage.ai/v1", model_provider="openai", model="solar-pro3", api_key=os.environ.get("OPENAI_API_KEY"))
parser = StrOutputParser()

# 첫 번째 체인 구성
chain = prompt | model | parser

# 요약 요청 프롬프트
summary_prompt = ChatPromptTemplate.from_template(
    """
    너는 아래의 대화를 1~2문장으로 요약하는 요약가야.

    대화 내용:
    {dialogue}
    """
)

# 두 번째 체인 구성
summary_chain = summary_prompt | model | parser


# =============================================
# 대화 히스토리 및 요약 관리
# =============================================
history = []

def chat(user_input):
    # History List를 하나의 문자열로 변경
    formatted_history = "\n".join([f"{m['role']}: {m['content']}" for m in history])

    # Chain 시작! (LLM 답변 출력됨)
    response = chain.invoke({"input": user_input, "history": formatted_history})

    # History List에 질문과 대화 추가하기
    history.append({"role": "user", "content": user_input})
    history.append({"role": "assistant", "content": response})

    print(f'[시스템 안내] 총 {len(history)} 대화가 기억되고 있습니다.')

    # 히스토리가 8칸 이상이면 오래된 4칸 요약
    if len(history) >= 8:
        # 가장 오래된 5 Turn 대화 이력을 하나의 Text로 만듦
        old_messages = history[:4]
        old_text = "\n".join([f"{m['role']}: {m['content']}" for m in old_messages])

        # 요약 실행!
        summary = summary_chain.invoke({"dialogue": old_text})

        # 5개 Turn 대화내용 삭제 후, 요약을 집어넣음
        del history[:4]
        history.insert(0, {"role": "system", "content": f"이전 대화 요약: {summary}"})

        # 로그 출력
        print('[시스템 안내] 4 Turn의 대화 내용을 다음과 같이 요약합니다.')
        print(f' >> {summary}')

    return response


# =============================================
# 대화 루프
# =============================================
print("🍔 미식가 챗봇에 오신 걸 환영합니다!")
print("대화를 종료하려면 'bye'를 입력하세요.\n")

while True:
    user_input = input("👤 인간 : ")

    ai_reply = chat(user_input)
    print(f"🤖 미식가 AI : {ai_reply}\n")

    if user_input == 'bye':
        break
# Out:
# 🍔 미식가 챗봇에 오신 걸 환영합니다!
# 대화를 종료하려면 'bye'를 입력하세요.
# 👤 인간 :  햄버거
# [시스템 안내] 총 2 대화가 기억되고 있습니다.
# 🤖 미식가 AI : 아, 햄버거라 하면 바삭한 번 사이에 육즙 가득한 패티, 신선한 양상추와 토마토, 그리고 달콤한 양파링이 떠오르죠! 완벽한 밸런스를 위해 체다 치즈와 새콤한 피클도 잊지 말아야 해요. 🍔✨
# 직접 만들어 보실 때는 패티를 3분 이상 구워 내부 온도 71℃까지 익히면 안전하답니다.
# 고소한 버터 향이 밴 번은 토스터나 팬에 살짝 구워주세요.
# 마지막으로 아보카도나 특제 소스를 추가하면 프리미엄 레벨이 완성돼요!
# (🍴 지금 바로 도전해보고 싶은 레시피가 있다면 알려주세요!)
# 👤 인간 :  bye
# [시스템 안내] 총 4 대화가 기억되고 있습니다.
# 🤖 미식가 AI : 그럼 다음에 또 만나요! 🥰 맛있는 이야기로 다시 돌아올게요—햄버거 얘기든, 새로운 레시피든 언제든지 환영이에요. 안녕! 🌟

# %% [markdown]
# # 2. AI Agent 개발하기

# %% [markdown]
# ### AI Agent란?

# %% [markdown]
# - AI Agent란, LLM이 스스로 필요한 함수(도구)를 호출해야겠다고 판단하여 호출하는 것을 뜻합니다.
#   - 예시
#     - LLM과 대화중에, LLM이 스스로 "사용자가 날씨가 궁금하구나?" 라고 판단이 되면 날씨 API를 호출합니다. (웹)
#     - LLM과 대화중에, 방에 불을 켜고 싶구나? 판단이 되면 방 불을 켜는 명령어를 날립니다. (임베디드)
#     - LLM과 대화중에, 전화를 걸고 싶구나? 판단이 되면 전화를 걸어줍니다. (모바일)

# %% [markdown]
# ### 간단한 AI Agent 개발해보기
# - LLM이 사용할 수 있는 함수(도구)를 만들어둡니다.
# - LLM이 사용자 질문에 따라 덧셈과 뺄셈 도구를 사용할 수있게 코딩해봅시다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - LLM이 ["add_sum", 3, 4] 형태의 포맷을 반환했을 경우, 실제 함수가 호출되도록 구현할 수 있습니다.
#   - 파이썬으로 이렇게 구현하면 됩니다.
#     - add_sum, add_minus 함수를 제작합니다.
#   - 아래와 같은 절차를 따릅니다.
#       1. LLM에게 질문을 줍니다.
#       2. LLM이 답변을 합니다. (함수호출이 필요하면 특정 포맷으로 반환하라고 합니다.)
#       3. LLM이 특정 포맷으로 답변했습니다.
#       4. 포맷 내용 분석 후, add_sum / add_minus 중 하나를 호출합니다.

# %% [markdown]
# - 아래 코드는 특정 포맷으로 답변하고, 해당 함수를 호출하지 않습니다.
#   - 아래 코드를 먼저 이해하고, 함수를 실제로 호출하는 코드도 소개할 예정입니다.

# %%
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Component 준비 (Workflow의 각 구성요소)
prompt = ChatPromptTemplate.from_template("""
    다음 질문에 답변만 해 줘.<질문> : {question}
    만약 아래 도구를 사용하여 질문을 해결하는데 도움이 될 수 있다면,
    해당되는 도구의 설명대로 답변해 주고, 도구가 답변에 도움이 되지 않는다면, 도구는 무시하시오.

    [도구 1]
    - 이름 : add_sum
    - 설명 : 두 수의 합을 반환한다.
    - 출력
      - 만약 3, 4의 합이 필요한 경우라고 판단되면 다음 줄과 같이 단답형으로만 답변해.
      ["add_sum", 3, 4]

    [도구 2]
    - 이름 : add_minus
    - 설명 : 두 수의 차를 반환한다.
    - 출력
      - 만약 5, 1의 차가 필요한 경우라고 판단되면 다음 줄과 같이 단답형으로만 답변해.
      ["add_minus", 5, 1]
""")
# model = init_chat_model("openai:gpt-4o-mini")
model = init_chat_model(base_url="https://api.upstage.ai/v1", model_provider="openai", model="solar-pro3", api_key=os.environ.get("OPENAI_API_KEY"))
parser = StrOutputParser()

# 체인 구성 (prompt --> model --> parser)
chain = prompt | model | parser

# =============================================
# 대화 루프
# =============================================
print("AI Agent 챗봇에 오신 걸 환영합니다!")
print("대화를 종료하려면 'bye'를 입력하세요.\n")
print(f"🤖 AI : 무엇이든 질문하세요")

while True:
    user_input = input("👤 인간 : ")
    ai_reply = chain.invoke({"question": user_input})

    print(f"🤖 AI : {ai_reply}\n")

    if user_input == 'bye':
        break
# Out:
# AI Agent 챗봇에 오신 걸 환영합니다!
# 대화를 종료하려면 'bye'를 입력하세요.
#
# 🤖 AI : 무엇이든 질문하세요
# 👤 인간 :  햄버거
# 🤖 AI : ["add_sum", 3, 4]
# 👤 인간 :  bye
# 🤖 AI : ["add_sum", 3, 4]

# %% [markdown]
# - 위 코드를 이해하셨다면, 이제 함수를 실제로 호출하는 코드를 넣어보겠습니다.

# %%
import re
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain.tools import tool

# Component 준비 (Workflow의 각 구성요소)
prompt = ChatPromptTemplate.from_template("""
    다음 질문에 답변만 해 줘.<질문> : {question}
    만약 아래 도구를 사용하여 질문을 해결하는데 도움이 될 수 있다면,
    해당되는 도구의 설명대로 답변해 주고, 도구가 답변에 도움이 되지 않는다면, 도구는 무시하시오.

    [도구 1]
    - 이름 : add_sum
    - 설명 : 두 수의 합을 반환한다.
    - 출력
      - 만약 3, 4의 합이 필요한 경우라고 판단되면 다음 줄과 같이 단답형으로만 답변해.
      ["add_sum", 3, 4]

    [도구 2]
    - 이름 : add_minus
    - 설명 : 두 수의 차를 반환한다.
    - 출력
      - 만약 5, 1의 차가 필요한 경우라고 판단되면 다음 줄과 같이 단답형으로만 답변해.
      ["add_minus", 5, 1]
""")

model = init_chat_model(base_url="https://api.upstage.ai/v1", model_provider="openai", model="solar-pro3", api_key=os.environ.get("OPENAI_API_KEY"))
parser = StrOutputParser()

# 체인 구성 (prompt --> model --> parser)
chain = prompt | model | parser


# =====================================================
# 도구 정의
# =====================================================
def add_sum(a, b):
  return a + b

def add_minus(a, b):
  return a - b

# 툴 구성
tools = {
    "add_sum": add_sum,
    "add_minus": add_minus
}


# =====================================================
# 도구 호출 문자열 검사 + 실행 함수
# =====================================================
def do_use_tool(ai_reply: str):
    ai_reply = ai_reply.splitlines()[0] # 첫번째 줄만 가져오기
    ai_reply = ai_reply.strip() # 문장 양쪽 공백 없애기
    # 정규식 검사, ["tool", a, b] 형태 포맷이 맞는지 검사
    pattern = r'^\s*\[\s*"(?P<tool>\w+)"\s*,\s*(?P<a>-?\d+)\s*,\s*(?P<b>-?\d+)\s*\]\s*$'
    match = re.match(pattern, ai_reply) # 검사 수행

    if match: #포맷이 맞다면?
        tool_name = match.group("tool") # 정규식 ["tool", a, b] 에서 "tool" 부분 추출
        a = int(match.group("a")) # 정규식 ["tool", a, b] 에서 a 부분 추출
        b = int(match.group("b")) # 정규식 ["tool", a, b] 에서 b 부분 추출

        if tool_name in tools:
            func = tools[tool_name]
            result = func(a, b) # 도구 사용하기!
            print(f"🛠️ 도구 수행 : {tool_name}({a}, {b}) = {result}")

# =============================================
# 대화 루프
# =============================================
print("AI Agent 챗봇에 오신 걸 환영합니다!")
print("대화를 종료하려면 'bye'를 입력하세요.\n")
print(f"🤖 AI : 무엇이든 질문하세요")

while True:
    print()
    user_input = input("👤 인간 : ")
    ai_reply = chain.invoke({"question": user_input})
    print(f"🤖 AI : {ai_reply}")

    do_use_tool(ai_reply) # 포맷 확인 후 함수 실행!

    if user_input == 'bye':
        break
# Out:
# AI Agent 챗봇에 오신 걸 환영합니다!
# 대화를 종료하려면 'bye'를 입력하세요.
#
# 🤖 AI : 무엇이든 질문하세요
# 👤 인간 :  햄버거
# 🤖 AI : "add_sum", 3, 4
# 👤 인간 :  bye
# 🤖 AI : ["add_sum", 3, 4]
# 🛠️ 도구 수행 : add_sum(3, 4) = 7

# %% [markdown]
# - LLM이 직접 필요한 함수를 호출한 것과 동일한 효과입니다.
#   - 이것이 AI Agent입니다.
#     - AI가 호출할 수 있는 함수를 Tool 이라고 합니다.
#     - 목표를 이해하고, 할수 있는 행동 중 필요한 Tool을 선택하여 사용하는 것입니다

# %% [markdown]
# ### Tool 사용 결과를 이해하는 AI Agent
# - 이번엔 LLM이 툴을 사용하는 것 뿐만 아니라, 그 결과를 이용하여 답변하도록 구현하겠습니다.
#   - 2개의 프롬프트가 필요합니다.
#     - 1) 툴을 사용해야하는지 판단하는 프롬프트
#     - 2) 툴 사용 결과를 포함하여, 다시 한번 제대로 질문하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import re
from langchain.chat_models import init_chat_model
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Component 준비 (도구 사용 전)
prompt1 = ChatPromptTemplate.from_template("""
    다음 질문에 도구가 필요한지 판단해줘 <질문> : {question}
    만약 아래 도구를 사용하여 질문을 해결하는데 도움이 될 수 있다면, 해당되는 도구의 설명대로 답변해줘.
    만약 도움이 되지 않는다면 "사용할 툴 없음" 이라고 답변해줘

    [도구 1]
    - 이름 : add_sum
    - 설명 : 두 수의 합을 반환한다.
    - 출력
      - 만약 3, 4의 합이 필요한 경우라고 판단되면 답변 예시 : ["add_sum", 3, 4]

    [도구 2]
    - 이름 : add_minus
    - 설명 : 두 수의 차를 반환한다.
    - 출력
      - 만약 5, 1의 차가 필요한 경우라고 판단되면 답변 예시 : ["add_minus", 5, 1]
""")

model = init_chat_model(base_url="https://api.upstage.ai/v1", model_provider="openai", model="solar-pro3", api_key=os.environ.get("OPENAI_API_KEY"))
parser = StrOutputParser()

# 체인 구성 (prompt --> model --> parser)
chain1 = prompt1 | model | parser

# Component 준비 (도구 사용 후)
prompt2 = ChatPromptTemplate.from_template("""
    다음 질문에 대답해줘 <질문> : {question}
    그리고 힌트를 주자면, 위 질문에 대해 도움이 되는 툴을 실행 결과야
    수행한 툴 : {tool_text}
    툴의 결과 : {tool_result}
""")

# 체인 구성 (prompt --> model --> parser)
chain2 = prompt2 | model | parser


# =====================================================
# 도구 정의
# =====================================================
def add_sum(a, b):
    return a + b

def add_minus(a, b):
    return a - b

# 툴 구성
tools = {
    "add_sum": add_sum,
    "add_minus": add_minus
}

# =====================================================
# 도구 호출 문자열 검사 + 실행 함수
# =====================================================
def do_use_tool(ai_reply: str):
    ai_reply = ai_reply.splitlines()[0] # 첫번째 줄만 가져오기
    ai_reply = ai_reply.strip() # 문장 양쪽 공백 없애기
    # 정규식 검사, ["tool", a, b] 형태 포맷이 맞는지 검사
    pattern = r'^\s*\[\s*"(?P<tool>\w+)"\s*,\s*(?P<a>-?\d+)\s*,\s*(?P<b>-?\d+)\s*\]\s*$'
    match = re.match(pattern, ai_reply) # 검사 수행

    if match: #포맷이 맞다면?
        tool_name = match.group("tool") # 정규식 ["tool", a, b] 에서 "tool" 부분 추출
        a = int(match.group("a")) # 정규식 ["tool", a, b] 에서 a 부분 추출
        b = int(match.group("b")) # 정규식 ["tool", a, b] 에서 b 부분 추출

        if tool_name in tools:
            func = tools[tool_name]
            result = func(a, b) # 도구 사용하기!
            print(f"🛠️ 도구 수행 : {tool_name}({a}, {b}) = {result}")
            return tool_name, result # 포맷이 맞으면 툴 이름과 함수 호출 결과 반환

    return None, None # 포맷이 다르다면 None, None 반환


# =============================================
# 대화 루프
# =============================================
print("AI Agent 챗봇에 오신 걸 환영합니다!")
print("대화를 종료하려면 'bye'를 입력하세요.\n")
print(f"🤖 AI Agent : 무엇이든 질문하세요")

while True:
    print()
    user_input = input("👤 인간 : ")
    ai_reply = chain1.invoke({"question": user_input})

    # 1차 LLM 사용 - 도구 사용 판단
    ai_reply = chain1.invoke({"question": user_input}).strip()
    print(f"🧠 1차 응답(생각) : {ai_reply}")

    # LLM 답변이 도구 사용을 하라는 의미인지 확인 후, 도구 사용하기
    # 도구를 사용하지 않았다면 (None, None) 반환
    tool_name, result = do_use_tool(ai_reply)

    ai_reply = chain2.invoke({
        "question": user_input,
        "tool_text": tool_name,
        "tool_result": result
    })

    print(f"🤖 AI Agent : {ai_reply}")

    if user_input == 'bye':
        break
# Out:
# AI Agent 챗봇에 오신 걸 환영합니다!
# 대화를 종료하려면 'bye'를 입력하세요.
#
# 🤖 AI Agent : 무엇이든 질문하세요
# 👤 인간 :  햄버거
# 🧠 1차 응답(생각) : 사용할 툴 없음
# 햄버거는 음식 항목이며, 제시된 도구(add_sum, add_minus)는 수학적 연산을 위한 도구입니다. 두 도구 모두 숫자 계산에 특화되어 있어 햄버거 관련 질문에 적용할 수 없습니다.
# 🤖 AI Agent : 햄버거는 패티(주로 소고기), 빵, 다양한 채소(양상추, 토마토 등), 소스 등을 조합해 만드는 대표적인 패스트푸드입니다. 주요 구성 요소와 특징을 정리해 드릴게요:
#
# 1. **역사**: 1880년대 독일 이민자 찰스 나단이 미국에서 "햄버거 스테이크"를 개발했고, 1904년 세인트루이스 박람회에서 빵에 넣은 형태로 선보였습니다.
# 2. **종류**:
#    - 클래식: 치즈, 베이컨 추가 옵션
#    - 채식: 콩/버섯 패티 활용
#    - 지역별 변형 (예: 한국 '불고기버거', 일본 '와규버거')
# 3. **영양**: 1개 기준 약 250-500kcal, 단백질과 지방 함량이 높습니다.
# 4. **산업**: 맥도날드(1940년대 등장), 버거킹(1954년) 등이 글로벌 프랜차이즈로 성장했습니다.
#
# 툴 실행 결과가 없으므로 기본적인 정보를 제공했습니다. 더 구체적인 내용(예: 레시피, 건강 영향 등)이 필요하면 알려주세요!
# 👤 인간 :  bye
# 🧠 1차 응답(생각) : 사용할 툴 없음
#
# **이유**:
# 질문이 "bye"로, 단순히 종료 의사를 표현하는 문장이므로 제공된 도구([add_sum], [add_minus])의 수학적 연산과 무관한 상황입니다. 따라서 도구 사용이 필요하지 않습니다.
# 🤖 AI Agent : 안녕하세요! 현재 사용 중인 언어 모델은 **Solar Pro 3**이며, Upstage에서 개발한 최신 AI입니다.
#
# 질문에 대한 답변은 다음과 같습니다:
# **"Bye"**는 작별 인사로 해석됩니다. 추가 설명이나 도움이 필요하시면 언제든 알려주세요! 😊
#
# 혹시 특정 주제나 기능에 대한 자세한 설명이 필요하신가요? 예를 들어:
# - Solar Pro 3의 성능
# - Upstage의 AI 서비스
# - 한국어/일본어 지원 관련 기능
#
# 도움을 드릴 수 있는 다른 방법이 있다면 언제든지 말씀해주세요!

# %% [markdown]
# - 위 동작을 다음과 같이 표현할 수 있습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. ReAct(Reasoning And Acting) 이해하기

# %% [markdown]
# - Reasoning 이란?
#   - AI가 논리적인 사고를 하는 것을 Reasoning 이라고 합니다.
#   - 질문을 논리적으로 전개하여 생각하는 것입니다.
#   - 예시
#     - 질문 : 3만원씩 용돈받는 철수가, 4달치 모아서 10만원짜리 포켓몬 카드를 살수있을까?
#     - Reasoning 1 : 3만원씩 용돈을 4달치 모으면 곱셈을 하면되며, 총 12만원이다.
#     - Reasoning 2 : 12만원에서 10만원어치 구매하면, 2만원이 남고 살 수 있다.
#     - 대답 : 네, 포켓몬카드를 사고 2만원이 남습니다.
#
# <br/>
#
# - Acting은 AI가 Tool을 사용하는 것을 뜻합니다.
#
# <br/>
#
# - **ReAct는 AI Agent가 논리적인 생각과 행동을 반복하는 아래와 같은 구조를 뜻합니다.**
#   - 어려운 개념이아닙니다. Google에서 아래와 같은 구조에 이름을 붙인 것 뿐입니다.
#   - 반복적인 사고와 Tool의 실행으로 최종적인 답변을 얻어내고자 하는 구조입니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 무한 루프가 돌 수도 있습니다!
#   - Observation 단계에서 최종 대답을 결정하지 않고, 계속 툴이 필요하다고 오작동 될수도 있습니다.
#   - 이 경우 최대 Cycle 수를 설정하거나, Tool을 한번씩만 수행하도록 제한을 걸 수 있습니다.

# %% [markdown]
# - 직접 구현 하는건 많이 복잡합니다!
#   - 프롬프팅도 잘해야하고, LLM이 되게 자주 호출될꺼예요.
#   - 무한루프도 발생되지 않게해야하고, 디버깅도 오래걸릴꺼예요.
#   - **직접 구현 하는 방법은 생략하겠습니다!**

# %% [markdown]
# # 4. LangChain 1 세대 수업 종료!(1.0버전 이전), 이제 2세대 LangChain 소개 시작!(1.0버전 부터)
# ### 고생하셨습니다
# - 여기까지 하시느라 고생하셨습니다.
#   - 여기까지 전통적인 LangChain에 대해 알아봤습니다.
# - 래딧에 누군가가 이런말을 했는데요. 완전 동의합니다.
#   - 1 세대 AI App : AI Workflow 중심
#   - 2 세대 AI App : Agent 중심
# - 지금부터 Agent 중심으로 LangChain을 다루는 방법을 알아볼 것입니다.
#   - 먼저 ReAct를 LangChain에서 어떻게 구현하는지 보겠습니다.
#   - 이후 LangChain의 역사에 대해 알아보겠습니다.
#
# - 아래 코드는 https://docs.langchain.com/oss/python/langchain/quickstart 코드를 참고하였습니다.

# %%
# 랭체인 공식 버전으로 설치됩니다 (에러는 무시하셔도 됩니다.)
# !pip install --upgrade --force-reinstall \
  "langchain-core==1.2.17" \
  "langchain==1.2.12" \
  "langgraph==1.1.2" \
  "langchain-openai==1.1.0" \
  "langchain-upstage==0.7.7" \
  "langchain-text-splitters==1.1.1" \
  "langchain-classic==1.0.2" \
  "transformers==4.46.0" \
  "tokenizers==0.20.3"
# Out:
# Collecting langchain-core==1.2.17
#   Using cached langchain_core-1.2.17-py3-none-any.whl.metadata (4.4 kB)
# Collecting langchain==1.2.12
#   Using cached langchain-1.2.12-py3-none-any.whl.metadata (5.7 kB)
# Collecting langgraph==1.1.2
#   Using cached langgraph-1.1.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting langchain-openai==1.1.0
#   Using cached langchain_openai-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-upstage==0.7.7
#   Using cached langchain_upstage-0.7.7-py3-none-any.whl.metadata (3.3 kB)
# Collecting langchain-text-splitters==1.1.1
#   Using cached langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting langchain-classic==1.0.2
#   Using cached langchain_classic-1.0.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting transformers==4.46.0
#   Using cached transformers-4.46.0-py3-none-any.whl.metadata (44 kB)
# Collecting tokenizers==0.20.3
#   Using cached tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core==1.2.17)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core==1.2.17)
#   Using cached langsmith-0.7.17-py3-none-any.whl.metadata (15 kB)
# Collecting packaging>=23.2.0 (from langchain-core==1.2.17)
#   Using cached packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain-core==1.2.17)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core==1.2.17)
#   Using cached pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core==1.2.17)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting typing-extensions<5.0.0,>=4.7.0 (from langchain-core==1.2.17)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core==1.2.17)
#   Using cached uuid_utils-0.14.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph==1.1.2)
#   Using cached langgraph_checkpoint-4.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.8 (from langgraph==1.1.2)
#   Using cached langgraph_prebuilt-1.0.8-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph==1.1.2)
#   Using cached langgraph_sdk-0.3.11-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph==1.1.2)
#   Using cached xxhash-3.6.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting openai<3.0.0,>=1.109.1 (from langchain-openai==1.1.0)
#   Using cached openai-2.26.0-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai==1.1.0)
#   Using cached tiktoken-0.12.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.7 kB)
# Collecting pypdf<7.0.0,>=4.2.0 (from langchain-upstage==0.7.7)
#   Using cached pypdf-6.8.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting requests<3.0.0,>=2.31.0 (from langchain-upstage==0.7.7)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting urllib3<3,>=2.6.3 (from langchain-upstage==0.7.7)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers==0.20.3)
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Collecting sqlalchemy<3.0.0,>=1.4.0 (from langchain-classic==1.0.2)
#   Using cached sqlalchemy-2.0.48-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting filelock (from transformers==4.46.0)
#   Using cached filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Collecting numpy>=1.17 (from transformers==4.46.0)
#   Using cached numpy-2.4.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting regex!=2019.12.17 (from transformers==4.46.0)
#   Using cached regex-2026.2.28-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting safetensors>=0.4.1 (from transformers==4.46.0)
#   Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting tqdm>=4.27 (from transformers==4.46.0)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.16.4->tokenizers==0.20.3)
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.16.4->tokenizers==0.20.3)
#   Using cached hf_xet-1.4.1-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core==1.2.17)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph==1.1.2)
#   Using cached ormsgpack-1.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph==1.1.2)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph==1.1.2)
#   Using cached orjson-3.11.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core==1.2.17)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core==1.2.17)
#   Using cached zstandard-0.25.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.3 kB)
# Collecting anyio (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph==1.1.2)
#   Using cached anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting certifi (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph==1.1.2)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph==1.1.2)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph==1.1.2)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph==1.1.2)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=1.109.1->langchain-openai==1.1.0)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=1.109.1->langchain-openai==1.1.0)
#   Using cached jiter-0.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting sniffio (from openai<3.0.0,>=1.109.1->langchain-openai==1.1.0)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain-core==1.2.17)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain-core==1.2.17)
#   Using cached pydantic_core-2.41.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain-core==1.2.17)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.31.0->langchain-upstage==0.7.7)
#   Using cached charset_normalizer-3.4.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (39 kB)
# Collecting greenlet>=1 (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic==1.0.2)
#   Using cached greenlet-3.3.2-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# WARNING: The candidate selected for download or install is a yanked version: 'transformers' candidate (version 4.46.0 at https://files.pythonhosted.org/packages/db/88/1ef8a624a33d7fe460a686b9e0194a7916320fc0d67d4e38e570beeac039/transformers-4.46.0-py3-none-any.whl (from https://pypi.org/simple/transformers/) (requires-python:>=3.8.0))
# Reason for being yanked: This version unfortunately does not work with 3.8 but we did not drop the support yet
# Using cached langchain_core-1.2.17-py3-none-any.whl (502 kB)
# Using cached langchain-1.2.12-py3-none-any.whl (112 kB)
# Using cached langgraph-1.1.2-py3-none-any.whl (167 kB)
# Using cached langchain_openai-1.1.0-py3-none-any.whl (84 kB)
# Using cached langchain_upstage-0.7.7-py3-none-any.whl (26 kB)
# Using cached tokenizers-0.20.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Using cached langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Using cached langchain_classic-1.0.2-py3-none-any.whl (1.0 MB)
# Using cached transformers-4.46.0-py3-none-any.whl (10.0 MB)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# Using cached hf_xet-1.4.1-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
# Using cached langgraph_prebuilt-1.0.8-py3-none-any.whl (35 kB)
# Using cached langgraph_sdk-0.3.11-py3-none-any.whl (94 kB)
# Using cached langsmith-0.7.17-py3-none-any.whl (359 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached openai-2.26.0-py3-none-any.whl (1.1 MB)
# Using cached anyio-4.12.1-py3-none-any.whl (113 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (362 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached pypdf-6.8.0-py3-none-any.whl (332 kB)
# Using cached pyyaml-6.0.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (806 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.5-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached sqlalchemy-2.0.48-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.3 MB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached tiktoken-0.12.0-cp311-cp311-manylinux_2_28_x86_64.whl (1.2 MB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached uuid_utils-0.14.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (345 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached greenlet-3.3.2-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (594 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached numpy-2.4.3-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
# Using cached orjson-3.11.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (133 kB)
# Using cached ormsgpack-1.12.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
# Using cached packaging-26.0-py3-none-any.whl (74 kB)
# Using cached regex-2026.2.28-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (800 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached xxhash-3.6.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Using cached zstandard-0.25.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.6 MB)
# Using cached filelock-3.25.2-py3-none-any.whl (26 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, urllib3, typing-extensions, tqdm, tenacity, sniffio, safetensors, regex, pyyaml, pypdf, packaging, ormsgpack, orjson, numpy, jsonpointer, jiter, idna, hf-xet, h11, greenlet, fsspec, filelock, distro, charset_normalizer, certifi, annotated-types, typing-inspection, sqlalchemy, requests, pydantic-core, jsonpatch, httpcore, anyio, tiktoken, requests-toolbelt, pydantic, huggingface-hub, httpx, tokenizers, openai, langsmith, langgraph-sdk, transformers, langchain-core, langgraph-checkpoint, langchain-text-splitters, langchain-openai, langgraph-prebuilt, langchain-upstage, langchain-classic, langgraph, langchain
#   Attempting uninstall: zstandard
#     Found existing installation: zstandard 0.25.0
#     Uninstalling zstandard-0.25.0:
#       Successfully uninstalled zstandard-0.25.0
#   Attempting uninstall: xxhash
#     Found existing installation: xxhash 3.6.0
#     Uninstalling xxhash-3.6.0:
#       Successfully uninstalled xxhash-3.6.0
#   Attempting uninstall: uuid-utils━━━━━━━━━━━━━━━━━━━━━━━  1/54 [xxhash]
#     Found existing installation: uuid_utils 0.14.1━━━  1/54 [xxhash]
#     Uninstalling uuid_utils-0.14.1:━━━━━━━━━━━━━━━━━━  1/54 [xxhash]
#       Successfully uninstalled uuid_utils-0.14.1━━━━━  1/54 [xxhash]
#   Attempting uninstall: urllib3━━━━━━━━━━━━━━━━━━━━━━  1/54 [xxhash]
#     Found existing installation: urllib3 2.6.3━━━━━━━  1/54 [xxhash]
#     Uninstalling urllib3-2.6.3:━━━━━━━━━━━━━━━━━━━━━━  1/54 [xxhash]
#       Successfully uninstalled urllib3-2.6.3━━━━━━━━━  1/54 [xxhash]
#   Attempting uninstall: typing-extensions━━━━━━━━━━━━━━━━━━━━━━━━━  3/54 [urllib3]
#     Found existing installation: typing_extensions 4.15.0━━━━━  3/54 [urllib3]
#     Uninstalling typing_extensions-4.15.0:━━━━━━━━━━━━━━━━━━━━  3/54 [urllib3]
#       Successfully uninstalled typing_extensions-4.15.0━━━━━━━━━━━  4/54 [typing-extensions]
#   Attempting uninstall: tqdm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/54 [typing-extensions]
#     Found existing installation: tqdm 4.67.3━━━━━━━━━━━━━━━━━━  4/54 [typing-extensions]
#     Uninstalling tqdm-4.67.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/54 [typing-extensions]
#       Successfully uninstalled tqdm-4.67.3━━━━━━━━━━━━━━━━━━━━━━━━  5/54 [tqdm]tensions]
#   Attempting uninstall: tenacity━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/54 [tqdm]
#     Found existing installation: tenacity 9.1.4━━━━━━━━━━━━━━━  5/54 [tqdm]
#     Uninstalling tenacity-9.1.4:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/54 [tqdm]
#       Successfully uninstalled tenacity-9.1.4━━━━━━━━━━━━━━━━━  5/54 [tqdm]
#   Attempting uninstall: sniffio━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/54 [tqdm]
#     Found existing installation: sniffio 1.3.1━━━━━━━━━━━━━━━━  5/54 [tqdm]
#     Uninstalling sniffio-1.3.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/54 [tqdm]
#       Successfully uninstalled sniffio-1.3.1━━━━━━━━━━━━━━━━━━  5/54 [tqdm]
#   Attempting uninstall: safetensors━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/54 [sniffio]
#     Found existing installation: safetensors 0.7.0━━━━━━━━━━━━  7/54 [sniffio]
#     Uninstalling safetensors-0.7.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/54 [sniffio]
#       Successfully uninstalled safetensors-0.7.0━━━━━━━━━━━━━━  7/54 [sniffio]
#   Attempting uninstall: regex━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/54 [sniffio]
#     Found existing installation: regex 2026.2.28━━━━━━━━━━━━━━  7/54 [sniffio]
#     Uninstalling regex-2026.2.28:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  7/54 [sniffio]
#       Successfully uninstalled regex-2026.2.28━━━━━━━━━━━━━━━━  7/54 [sniffio]
#   Attempting uninstall: pyyaml90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/54 [regex]
#     Found existing installation: PyYAML 6.0.3━━━━━━━━━━━━━━━━━  9/54 [regex]
#     Uninstalling PyYAML-6.0.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  9/54 [regex]
#       Successfully uninstalled PyYAML-6.0.3━━━━━━━━━━━━━━━━━━━  9/54 [regex]
#   Attempting uninstall: pypdf━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/54 [pyyaml]
#     Found existing installation: pypdf 6.8.0━━━━━━━━━━━━━━━━━━ 10/54 [pyyaml]
#     Uninstalling pypdf-6.8.0:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/54 [pyyaml]
#       Successfully uninstalled pypdf-6.8.0━━━━━━━━━━━━━━━━━━━━ 10/54 [pyyaml]
#   Attempting uninstall: packaging0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/54 [pypdf]
#     Found existing installation: packaging 26.0━━━━━━━━━━━━━━━ 11/54 [pypdf]
#     Uninstalling packaging-26.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/54 [pypdf]
#       Successfully uninstalled packaging-26.0━━━━━━━━━━━━━━━━━ 11/54 [pypdf]
#   Attempting uninstall: ormsgpack━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/54 [pypdf]
#     Found existing installation: ormsgpack 1.12.2━━━━━━━━━━━━━ 11/54 [pypdf]
#     Uninstalling ormsgpack-1.12.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/54 [pypdf]
#       Successfully uninstalled ormsgpack-1.12.2━━━━━━━━━━━━━━━ 11/54 [pypdf]
#   Attempting uninstall: orjsonm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/54 [ormsgpack]
#     Found existing installation: orjson 3.11.7━━━━━━━━━━━━━━━━ 13/54 [ormsgpack]
#     Uninstalling orjson-3.11.7:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/54 [ormsgpack]
#       Successfully uninstalled orjson-3.11.7━━━━━━━━━━━━━━━━━━ 13/54 [ormsgpack]
#   Attempting uninstall: numpy90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/54 [ormsgpack]
#     Found existing installation: numpy 2.4.3━━━━━━━━━━━━━━━━━━ 13/54 [ormsgpack]
#     Uninstalling numpy-2.4.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/54 [numpy]
#       Successfully uninstalled numpy-2.4.3━━━━━━━━━━━━━━━━━━━━ 15/54 [numpy]
#   Attempting uninstall: jsonpointer90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/54 [numpy]
#     Found existing installation: jsonpointer 3.0.0━━━━━━━━━━━━ 15/54 [numpy]
#     Uninstalling jsonpointer-3.0.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/54 [numpy]
#       Successfully uninstalled jsonpointer-3.0.0━━━━━━━━━━━━━━━━━━ 16/54 [jsonpointer]
#   Attempting uninstall: jiter━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/54 [jsonpointer]
#     Found existing installation: jiter 0.13.0━━━━━━━━━━━━━━━━━ 16/54 [jsonpointer]
#     Uninstalling jiter-0.13.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/54 [jsonpointer]
#       Successfully uninstalled jiter-0.13.0━━━━━━━━━━━━━━━━━━━ 16/54 [jsonpointer]
#   Attempting uninstall: idnam╸━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/54 [jiter]r]
#     Found existing installation: idna 3.11━━━━━━━━━━━━━━━━━━━━ 17/54 [jiter]
#     Uninstalling idna-3.11:━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/54 [jiter]
#       Successfully uninstalled idna-3.11━━━━━━━━━━━━━━━━━━━━━━ 17/54 [jiter]
#   Attempting uninstall: hf-xet━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/54 [jiter]
#     Found existing installation: hf-xet 1.4.1━━━━━━━━━━━━━━━━━ 17/54 [jiter]
#     Uninstalling hf-xet-1.4.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/54 [jiter]
#       Successfully uninstalled hf-xet-1.4.1━━━━━━━━━━━━━━━━━━━ 17/54 [jiter]
#   Attempting uninstall: h11╺━━━━━━━━━━━━━━━━━━━━━━━━━ 19/54 [hf-xet]
#     Found existing installation: h11 0.16.0━━━━━━━━━━━━━━━━━━━ 19/54 [hf-xet]
#     Uninstalling h11-0.16.0:━━━━━━━━━━━━━━━━━━━━━━━━━ 19/54 [hf-xet]
#       Successfully uninstalled h11-0.16.0━━━━━━━━━━━━━━━━━━━━━ 19/54 [hf-xet]
#   Attempting uninstall: greenlet━━━━━━━━━━━━━━━━━━━━━━━━━ 20/54 [h11]
#     Found existing installation: greenlet 3.3.2━━━━━━━━━━━━━━━ 20/54 [h11]
#     Uninstalling greenlet-3.3.2:━━━━━━━━━━━━━━━━━━━━━━━━━ 20/54 [h11]
#       Successfully uninstalled greenlet-3.3.2━━━━━━━━━━━━━━━━━ 20/54 [h11]
#   Attempting uninstall: fsspec0m━━━━━━━━━━━━━━━━━━━━━━━━━ 20/54 [h11]
#     Found existing installation: fsspec 2026.2.0━━━━━━━━━━━━━━ 20/54 [h11]
#     Uninstalling fsspec-2026.2.0:━━━━━━━━━━━━━━━━━━━━━━━━━ 20/54 [h11]
#       Successfully uninstalled fsspec-2026.2.0━━━━━━━━━━━━━━━━ 20/54 [h11]
#   Attempting uninstall: filelockm╺━━━━━━━━━━━━━━━━━━━━━━━ 22/54 [fsspec]
#     Found existing installation: filelock 3.25.2━━━━━━━━━━━━━━ 22/54 [fsspec]
#     Uninstalling filelock-3.25.2:m━━━━━━━━━━━━━━━━━━━━━━━ 22/54 [fsspec]
#       Successfully uninstalled filelock-3.25.2━━━━━━━━━━━━━━━━ 22/54 [fsspec]
#   Attempting uninstall: distro╺━━━━━━━━━━━━━━━━━━━━━━ 23/54 [filelock]
#     Found existing installation: distro 1.9.0━━━━━━━━━━━━━━━━━ 23/54 [filelock]
#     Uninstalling distro-1.9.0:╺━━━━━━━━━━━━━━━━━━━━━━ 23/54 [filelock]
#       Successfully uninstalled distro-1.9.0━━━━━━━━━━━━━━━━━━━ 23/54 [filelock]
#   Attempting uninstall: charset_normalizer━━━━━━━━━━━━━━━━━━━━ 23/54 [filelock]
#     Found existing installation: charset-normalizer 3.4.5━━━━━ 23/54 [filelock]
#     Uninstalling charset-normalizer-3.4.5:━━━━━━━━━━━━━━━━━━━━ 23/54 [filelock]
#       Successfully uninstalled charset-normalizer-3.4.5━━━━━━━━━━━ 25/54 [charset_normalizer]
#   Attempting uninstall: certifi╸━━━━━━━━━━━━━━━━━━━━━ 25/54 [charset_normalizer]
#     Found existing installation: certifi 2026.2.25━━━━━━━━━━━━ 25/54 [charset_normalizer]
#     Uninstalling certifi-2026.2.25:m━━━━━━━━━━━━━━━━━━━━━ 25/54 [charset_normalizer]
#       Successfully uninstalled certifi-2026.2.25━━━━━━━━━━━━━━ 25/54 [charset_normalizer]
#   Attempting uninstall: annotated-types0m━━━━━━━━━━━━━━━━━━━━━ 25/54 [charset_normalizer]
#     Found existing installation: annotated-types 0.7.0━━━━━━━━ 25/54 [charset_normalizer]
#     Uninstalling annotated-types-0.7.0:0m━━━━━━━━━━━━━━━━━━━━━ 25/54 [charset_normalizer]
#       Successfully uninstalled annotated-types-0.7.0━━━━━━━━━━ 25/54 [charset_normalizer]
#   Attempting uninstall: typing-inspection━━━━━━━━━━━━━━━━━━━━━ 25/54 [charset_normalizer]
#     Found existing installation: typing-inspection 0.4.2━━━━━━ 25/54 [charset_normalizer]
#     Uninstalling typing-inspection-0.4.2:━━━━━━━━━━━━━━━━━━━━━ 25/54 [charset_normalizer]
#       Successfully uninstalled typing-inspection-0.4.2━━━━━━━━ 25/54 [charset_normalizer]
#   Attempting uninstall: sqlalchemy0m━━━━━━━━━━━━━━━━━━━━━ 25/54 [charset_normalizer]
#     Found existing installation: SQLAlchemy 2.0.48━━━━━━━━━━━━ 25/54 [charset_normalizer]
#     Uninstalling SQLAlchemy-2.0.48:m━━━━━━━━━━━━━━━━━━━━━ 25/54 [charset_normalizer]
#       Successfully uninstalled SQLAlchemy-2.0.48━━━━━━━━━━━━━━ 25/54 [charset_normalizer]
#   Attempting uninstall: requestsm╺━━━━━━━━━━━━━━━━━━ 29/54 [sqlalchemy]zer]
#     Found existing installation: requests 2.32.5━━━━━━━━━━━━━━ 29/54 [sqlalchemy]
#     Uninstalling requests-2.32.5:m╺━━━━━━━━━━━━━━━━━━ 29/54 [sqlalchemy]
#       Successfully uninstalled requests-2.32.5━━━━━━━━━━━━━━━━ 29/54 [sqlalchemy]
#   Attempting uninstall: pydantic-core0m━━━━━━━━━━━━━━━━━━ 29/54 [sqlalchemy]
#     Found existing installation: pydantic_core 2.41.5━━━━━━━━━ 29/54 [sqlalchemy]
#     Uninstalling pydantic_core-2.41.5:m━━━━━━━━━━━━━━━━━━ 29/54 [sqlalchemy]
#       Successfully uninstalled pydantic_core-2.41.5━━━━━━━━━━━ 29/54 [sqlalchemy]
#   Attempting uninstall: jsonpatchm╸━━━━━━━━━━━━━━━━━ 31/54 [pydantic-core]
#     Found existing installation: jsonpatch 1.33━━━━━━━━━━━━━━━ 31/54 [pydantic-core]
#     Uninstalling jsonpatch-1.33:91m╸━━━━━━━━━━━━━━━━━ 31/54 [pydantic-core]
#       Successfully uninstalled jsonpatch-1.33━━━━━━━━━━━━━━━━ 32/54 [jsonpatch]
#   Attempting uninstall: httpcore╸━━━━━━━━━━━━━━━━ 32/54 [jsonpatch]
#     Found existing installation: httpcore 1.0.9━━━━━━━━━━━━━━━ 32/54 [jsonpatch]
#     Uninstalling httpcore-1.0.9:╸━━━━━━━━━━━━━━━━ 32/54 [jsonpatch]
#       Successfully uninstalled httpcore-1.0.9m━━━━━━━━━━━━━━━━ 32/54 [jsonpatch]
#   Attempting uninstall: anyio0m╸━━━━━━━━━━━━━━━━ 32/54 [jsonpatch]
#     Found existing installation: anyio 4.12.1m━━━━━━━━━━━━━━━━ 32/54 [jsonpatch]
#     Uninstalling anyio-4.12.1:m╸━━━━━━━━━━━━━━━━ 32/54 [jsonpatch]
#       Successfully uninstalled anyio-4.12.190m━━━━━━━━━━━━━━━━ 32/54 [jsonpatch]
#   Attempting uninstall: tiktoken━╺━━━━━━━━━━━━━━ 34/54 [anyio]
#     Found existing installation: tiktoken 0.12.0━━━━━━━━━━━━━━ 34/54 [anyio]
#     Uninstalling tiktoken-0.12.0:╺━━━━━━━━━━━━━━ 34/54 [anyio]
#       Successfully uninstalled tiktoken-0.12.00m━━━━━━━━━━━━━━ 34/54 [anyio]
#   Attempting uninstall: requests-toolbelt0m━━━━━━━━━━━━━━ 34/54 [anyio]
#     Found existing installation: requests-toolbelt 1.0.0━━━━━━ 34/54 [anyio]
#     Uninstalling requests-toolbelt-1.0.0:0m━━━━━━━━━━━━━━ 34/54 [anyio]
#       Successfully uninstalled requests-toolbelt-1.0.0━━━━━━━━ 34/54 [anyio]
#   Attempting uninstall: pydantic━━╸━━━━━━━━━━━━━ 36/54 [requests-toolbelt]
#     Found existing installation: pydantic 2.12.5m━━━━━━━━━━━━━ 36/54 [requests-toolbelt]
#     Uninstalling pydantic-2.12.5:m╸━━━━━━━━━━━━━ 36/54 [requests-toolbelt]
#       Successfully uninstalled pydantic-2.12.590m━━━━━━━━━━━━━ 36/54 [requests-toolbelt]
#   Attempting uninstall: huggingface-hub╺━━━━━━━━━━━━ 37/54 [pydantic]belt]
#     Found existing installation: huggingface_hub 0.36.2━━━━━━━ 37/54 [pydantic]
#     Uninstalling huggingface_hub-0.36.2:╺━━━━━━━━━━━━ 37/54 [pydantic]
#       Successfully uninstalled huggingface_hub-0.36.2━━━━━━━━━ 37/54 [pydantic]
#   Attempting uninstall: httpx━━━━━━━╺━━━━━━━━━━━ 38/54 [huggingface-hub]
#     Found existing installation: httpx 0.28.1m━━━━━━━━━━━ 38/54 [huggingface-hub]
#     Uninstalling httpx-0.28.1:━━╺━━━━━━━━━━━ 38/54 [huggingface-hub]
#       Successfully uninstalled httpx-0.28.1━━━━━━━━━━━ 38/54 [huggingface-hub]
#   Attempting uninstall: tokenizers0m╺━━━━━━━━━━━ 38/54 [huggingface-hub]
#     Found existing installation: tokenizers 0.20.3m━━━━━━━━━━━ 38/54 [huggingface-hub]
#     Uninstalling tokenizers-0.20.3:m╺━━━━━━━━━━━ 38/54 [huggingface-hub]
#       Successfully uninstalled tokenizers-0.20.3━━━━━━━━━━ 40/54 [tokenizers]]
#   Attempting uninstall: openai━━━╸━━━━━━━━━━ 40/54 [tokenizers]
#     Found existing installation: openai 2.26.0m━━━━━━━━━━ 40/54 [tokenizers]
#     Uninstalling openai-2.26.0:━━╸━━━━━━━━━━ 40/54 [tokenizers]
#       Successfully uninstalled openai-2.26.0━━━━━━━━━━ 40/54 [tokenizers]
#   Attempting uninstall: langsmith━━━━━╺━━━━━━━━━ 41/54 [openai]
#     Found existing installation: langsmith 0.7.17━━━━━━━━━ 41/54 [openai]
#     Uninstalling langsmith-0.7.17:╺━━━━━━━━━ 41/54 [openai]
#       Successfully uninstalled langsmith-0.7.17m━━━━━━━━━ 41/54 [openai]
#   Attempting uninstall: langgraph-sdk━━╺━━━━━━━━ 42/54 [langsmith]
#     Found existing installation: langgraph-sdk 0.3.11m━━━━━━━━ 42/54 [langsmith]
#     Uninstalling langgraph-sdk-0.3.11:m╺━━━━━━━━ 42/54 [langsmith]
#       Successfully uninstalled langgraph-sdk-0.3.1190m━━━━━━━━ 42/54 [langsmith]
#   Attempting uninstall: transformers╺━━━━━━━━ 42/54 [langsmith]
#     Found existing installation: transformers 4.46.00m━━━━━━━━ 42/54 [langsmith]
#     Uninstalling transformers-4.46.0:━━━╸━━━━━━━ 44/54 [transformers]
#       Successfully uninstalled transformers-4.46.0━━━━━━━ 44/54 [transformers]
#   Attempting uninstall: langchain-core━━╸━━━━━━━ 44/54 [transformers]
#     Found existing installation: langchain-core 1.2.12m━━━━━━━ 44/54 [transformers]
#     Uninstalling langchain-core-1.2.12:m╸━━━━━━━ 44/54 [transformers]
#       Successfully uninstalled langchain-core-1.2.1290m━━━━━━━ 44/54 [transformers]
#   Attempting uninstall: langgraph-checkpointm╺━━━━━━ 45/54 [langchain-core]
#     Found existing installation: langgraph-checkpoint 4.0.1━━━ 45/54 [langchain-core]
#     Uninstalling langgraph-checkpoint-4.0.1:0m╺━━━━━━ 45/54 [langchain-core]
#       Successfully uninstalled langgraph-checkpoint-4.0.1━━━━━ 45/54 [langchain-core]
#   Attempting uninstall: langchain-text-splitters━━━━━━ 45/54 [langchain-core]
#     Found existing installation: langchain-text-splitters 1.1.1 45/54 [langchain-core]
#     Uninstalling langchain-text-splitters-1.1.1:━━━━━━ 45/54 [langchain-core]
#       Successfully uninstalled langchain-text-splitters-1.1.1━ 45/54 [langchain-core]
#   Attempting uninstall: langchain-openai━━╸━━━━━ 47/54 [langchain-text-splitters]
#     Found existing installation: langchain-openai 1.1.00m━━━━━ 47/54 [langchain-text-splitters]
#     Uninstalling langchain-openai-1.1.0:0m╸━━━━━ 47/54 [langchain-text-splitters]
#       Successfully uninstalled langchain-openai-1.1.0━━━━━ 47/54 [langchain-text-splitters]
#   Attempting uninstall: langgraph-prebuilt╸━━━━━ 47/54 [langchain-text-splitters]
#     Found existing installation: langgraph-prebuilt 1.0.8━━━━━ 47/54 [langchain-text-splitters]
#     Uninstalling langgraph-prebuilt-1.0.8:╸━━━━━ 47/54 [langchain-text-splitters]
#       Successfully uninstalled langgraph-prebuilt-1.0.80m━━━━━ 47/54 [langchain-text-splitters]
#   Attempting uninstall: langchain-upstage━━━╺━━━ 49/54 [langgraph-prebuilt]s]
#     Found existing installation: langchain-upstage 0.7.790m━━━ 49/54 [langgraph-prebuilt]
#     Uninstalling langchain-upstage-0.7.7:╺━━━ 49/54 [langgraph-prebuilt]
#       Successfully uninstalled langchain-upstage-0.7.7━━━ 49/54 [langgraph-prebuilt]
#   Attempting uninstall: langchain-classic╺━━━ 49/54 [langgraph-prebuilt]
#     Found existing installation: langchain-classic 1.0.290m━━━ 49/54 [langgraph-prebuilt]
#     Uninstalling langchain-classic-1.0.2:━━━━╸━━ 51/54 [langchain-classic]
#       Successfully uninstalled langchain-classic-1.0.2m━━ 51/54 [langchain-classic]
#   Attempting uninstall: langgraph━━━━━━━━━━━━╸━━ 51/54 [langchain-classic]
#     Found existing installation: langgraph 1.1.21m╸━━ 51/54 [langchain-classic]
#     Uninstalling langgraph-1.1.2:━━━━━━━━╸━━ 51/54 [langchain-classic]
#       Successfully uninstalled langgraph-1.1.2╸━━ 51/54 [langchain-classic]
#   Attempting uninstall: langchain━━━━━━━━━━━━━╸━ 52/54 [langgraph]sic]
#     Found existing installation: langchain 1.2.121m╸━ 52/54 [langgraph]
#     Uninstalling langchain-1.2.12:━━━━━━━━╸━ 52/54 [langgraph]
#       Successfully uninstalled langchain-1.2.12╸━ 52/54 [langgraph]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54/54 [langchain]0m [langgraph]
# Successfully installed annotated-types-0.7.0 anyio-4.12.1 certifi-2026.2.25 charset_normalizer-3.4.5 distro-1.9.0 filelock-3.25.2 fsspec-2026.2.0 greenlet-3.3.2 h11-0.16.0 hf-xet-1.4.1 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-0.36.2 idna-3.11 jiter-0.13.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-1.2.12 langchain-classic-1.0.2 langchain-core-1.2.17 langchain-openai-1.1.0 langchain-text-splitters-1.1.1 langchain-upstage-0.7.7 langgraph-1.1.2 langgraph-checkpoint-4.0.1 langgraph-prebuilt-1.0.8 langgraph-sdk-0.3.11 langsmith-0.7.17 numpy-2.4.3 openai-2.26.0 orjson-3.11.7 ormsgpack-1.12.2 packaging-26.0 pydantic-2.12.5 pydantic-core-2.41.5 pypdf-6.8.0 pyyaml-6.0.3 regex-2026.2.28 requests-2.32.5 requests-toolbelt-1.0.0 safetensors-0.7.0 sniffio-1.3.1 sqlalchemy-2.0.48 tenacity-9.1.4 tiktoken-0.12.0 tokenizers-0.20.3 tqdm-4.67.3 transformers-4.46.0 typing-extensions-4.15.0 typing-inspection-0.4.2 urllib3-2.6.3 uuid-utils-0.14.1 xxhash-3.6.0 zstandard-0.25.0

# %%
from dataclasses import dataclass
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain.tools import tool

# =====================================================
# 시스템 프롬프트 (어떤 종류의 도구가 있음을 알리는건 LangChain의 권장사항 입니다.)
# =====================================================
SYSTEM_PROMPT = """너는 최고의 미식가야, 항상 간결하게 말하지
사용자가 요청하면 필요한 도구를 정확히 한 번만 사용하고

너에게는 세 개의 도구가 있어:

1. add_sum(a, b)
   - 두 수의 합을 구합니다.
2. add_minus(a, b)
   - 두 수의 차를 구합니다.
3. add_multiply(a, b)
   - 두 수의 곱을 구합니다.

결과를 이용해 농담 섞인 대답으로 답해줘.
"""


# =====================================================
# 도구 정의 (@tool 이라는 데코레이터는 권장사항입니다.)
# =====================================================
@tool
def add_sum(a: int, b: int) -> int:
    """두 수의 합을 구합니다."""
    return a + b

@tool
def add_minus(a: int, b: int) -> int:
    """두 수의 차를 구합니다."""
    return a - b

@tool
def add_multiply(a: int, b: int) -> int:
    """두 수의 곱을 구합니다."""
    return a * b

@tool
def get_weather() -> str:
    """오늘의 날씨를 반환합니다."""
    # API 호출 코드 삽입
    return "허리케인"

tool = [add_sum, add_minus, add_multiply, get_weather]


# =====================================================
# 모델 설정
# =====================================================
# model = init_chat_model("openai:gpt-4o-mini")
model = init_chat_model(base_url="https://api.upstage.ai/v1", model_provider="openai", model="solar-pro2", api_key=os.environ.get("OPENAI_API_KEY"))

# =====================================================
# 최종 결과 포맷
# =====================================================
@dataclass
class ResponseFormat:
    answer: str   # AI의 대답 문장


# =====================================================
# Agent 생성 (1.0버전 이전의 chain 대신에 쓰이는 부분)
# =====================================================

agent = create_agent(
    model=model,
    system_prompt=SYSTEM_PROMPT,
    tools=tool,
    response_format=ResponseFormat,
)

# =====================================================
# 실행 예시 (이쁘게 출력하려는 노력입니다.)
# =====================================================
def print_message(msgs):
  for msg in msgs:
      if hasattr(msg, "tool_calls") and msg.tool_calls:
          for tool_call in msg.tool_calls:
              name = tool_call.get("name")
              args = tool_call.get("args")
              if name == "ResponseFormat":
                  continue
              print(f"💭( 🛠️{name} 함수 호출 {args} )")

      if "AIMessage" not in str(type(msg)):
          print(f"💭( {type(msg).__name__} : {msg.content!r} )")


# =============================================
# 대화 루프
# =============================================
print("AI Agent 챗봇에 오신 걸 환영합니다!")
print("대화를 종료하려면 'bye'를 입력하세요.\n")
print(f"🤖 AI Agent : 무엇이든 질문하세요")

while True:
    print()
    user_input = input("👤 인간 : ")

    response = agent.invoke({
        "messages": [
            {"role": "user", "content": user_input}
        ]})

    print_message(response["messages"][1:-1])
    print(f"🤖 AI Agent : {response['structured_response'].answer}")

    if user_input == 'bye':
        break
# Out:
# AI Agent 챗봇에 오신 걸 환영합니다!
# 대화를 종료하려면 'bye'를 입력하세요.
#
# 🤖 AI Agent : 무엇이든 질문하세요
# 👤 인간 :  오늘 날씨는?
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 🤖 AI Agent : 오늘도 허리케인급 업무 폭풍을 뚫고 왔습니다. ☔️💨 비가 오는지 확인하셨다니, 당신은 진정한 생존자네요! (날씨: 허리케인)
# 👤 인간 :  bye
# 🤖 AI Agent : 잘 가요! 다음에 또 계산 부탁할 때 돌아오세요. (아, 참고로 0 - 0 = 0이라는 건 이미 알고 계시죠?)

# %% [markdown]
# - 구현방법이 기존과 다르죠?
#   - 기존에는 chain = prompt | model | parser 형태로 workflow를 표현했었습니다.
#   - 위 코드에는 이런 workflow 형태 코드가 보이지 않습니다!
#   - 이러한 새로운 개발방법이 LangChain 공식 버전에 생겼습니다.
#
# <br/>
#
# - 한번 LangChain의 역사를 보면서, 이게 어찌된 일인지 살펴보겠습니다.

# %% [markdown]
# # 5. LangChain 의 역사

# %% [markdown]
# ### LangChain의 출발점
# - LangChain은 통합된 AI App을 만들기 위해 시작되었습니다.
#   - AI 기능이 있는 App들은, 한 가지가 아닌 여러 AI Library들을 조합해서 AI App을 만들곤 합니다.
#     - 그런데 AI Library들 사용방법이 모두 다릅니다. ㅠㅠ 각각 공부해야합니다.
#     - 그리고 특정 AI Library 사용방법이 변경될 때 마다, 내 App도 유지보수 해줘야합니다.
#   - LangChain은 수 많은 AI Library을 똑같은 방법으로 사용할 수 있도록 합니다.
#     - AI Library들 각각 공부를 안해도 됩니다.
#     - AI Library들 사용방법이 똑같습니다.
#     - 손쉽게 여러 AI Library를 사용한 AI App을 만들 수 있습니다.
#   - **LangChain으로 AI Workflow를 손쉽게 개발할 수 있었습니다.**

# %% [markdown]
# ### 25년 10월 전까지, LangChain vs LangGraph
# - 24년 1월에 LangGraph가 출시되었고, LangChain의 입지가 애매모호해졌습니다.
#   - LangChain
#     - **랭체인은 단순한 AI Workflow를 제작할 때 쓰라고 합니다.**
#       - 예시 : A -> B -> C -> D 와 같이 순서대로 동작되는 Workflow
#     - 추가로 Tool 을 연동할 수 있습니다.
#   - LangGraph
#     - **더 복잡한 AI Workflow를 제작할 수 있습니다.**
#       - A -> B -> C -> 조건확인..Fail -> A -> B -> C -> 조건확인..Pass -> D -> E
#     - LangChain에서 만든 Component나 Chain을 사용할 수 있습니다.
#     - LangGraph를 AI Workflow 툴을 넘어 Workflow Orchestration(지휘자) 툴 이라고 소개합니다.

# %% [markdown]
# ### 25년 10월 이후, LangChain은 Workflow가 아닌 Agent를 만들기 위한 툴로 소개되기 시작합니다.
# - 25년 10월에 LangChain 공식버전 1.0이 출시되고 정의가 달라졌습니다.
#   - 1. LangChain은 Chain과 **Agentic App**을 쉽게 만드는 도구이다.
#   - 2. 복잡한 AI Workflow는 LangGraph로 만들어라
#   - 3. LangChain에서 만든 Component는 LangGraph에서 사용할 수 있다.
# - AI App들은 단순한 Workflow 보다는 ReAct 동작이 더 중요해졌기 때문입니다.
#   - 기존 Document는 chain = prompt | model | parser 와 같은 Workflow 중심으로 설명합니다.
#   - 신규 Document는 chain 설명이 제거되었고, Agent 코드를 더 우선적으로 설명합니다.
#     - Workflow는 LangGraph에서 구현하는 것을 강하게 권장합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 6. LangChain의 장점과 단점, Q&A

# %% [markdown]
# ### LangChain의 장점

# %% [markdown]
# - LLM 앱 개발에 필요한 많은 Component들이 모두 모여있습니다.
# - LLM API들을 동일한 방법으로 사용할 수 있습니다. (OpenAI, 클로드, Gemini 등)
# - 간단한 Workflow를 쉽게 구현할 수 있습니다.
# - RAG와 Tool을 쉽게 구현할 수 있습니다.
# - ReAct 구조의 AI Agent를 쉽게 구현할 수 있습니다.

# %% [markdown]
# ### LangChain의 단점

# %% [markdown]
# - 버전마다 문법이 조금씩 다릅니다. 호환이 안되는 경우가 많습니다.
#   - 블로그 / 인터넷 / GPT 자료가 최신인지 아닌지 구분하기 어렵습니다.
# - LangChain 공식버전이 나오고 방향성이 달라졌습니다. (혼란~!)
#   - Chain 기반 Workflow 중심 ---> Agent 중심으로 변경
#   - Workflow는 LangGraph에서 다루는 것을 권장합니다.
# - 자체적으로 디버깅이 불편합니다. 구조가 복잡해서 Log 출력 디버깅 힘들어요.
#   - LangSmith를 사용해야합니다.
# - LangChain 문서에 LangGraph 내용이 섞여있습니다. ^^;;;
#   - LangChain과 LangGraph의 경계선이 모호합니다.
#   - 공식문서가 랭체인을 잘 설명해주지 못합니다.
#     - Agent만 크게 강조해서 설명합니다.
#     - Component 단위로 Chain을 구성하는 내용을 삭제하였습니다.
# - 성능 최적화 / 안정화가 덜 되었습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Q&A
# - 지난 시간에 학습했던 Chain 방식은 더이상 안쓰이나요?
#   - 여전히 쓰입니다. **간단한 AI Workflow**를 만들 때 쓰입니다.
#   - 복잡한 AI Workflow는 랭그래프로 개발하는 것을 권장하고 있습니다.
#
# <br/>
#
# - 아예 랭체인 버리고, 랭그래프만 배우면 안되는 건가요?
#   - 랭그래프는, 랭체인의 확장팩으로 비유할 수 있습니다.
#     - 랭그래프를 배우기 전에, 랭체인을 알아야 이해하기 쉽습니다.
#     - 랭체인을 모르면, 랭그래프의 내부 동작을 이해하기 어렵습니다.
#
# <br/>
#
# - 랭체인은 그럼 앞으로 사라지나요?
#   - 아니요! 랭체인은 하나의 Component / Chain을 만들때 쓰입니다.
#     - 그리고 ReAct 구조의 간단한 Agentic App 만들때 쓰입니다.
#   - 랭그래프에서는 Component / Chain들을 연결하여 복잡한 Workflow를 만들 수 있습니다.
#   - 랭그래프를 Main Library로 사용하고, 랭체인은 랭그래프에 쓰일 부품(Node)를 만드는데 사용됩니다.
#
# <br/>
#
# - 랭그래프는 저희 수업에서 배우나요?
#   - 아쉽게도 LangChain까지만 배웁니다.
#   - LangGraph는 배운 지식을 기반으로 추가로 공부해보세요!

# %% [markdown]
# # 7. Agent를 활용한 Multi-turn 구현
#   - History를 기억하기 위한 InMemorySaver 라는 클래스가 제공됩니다.
#     - 랭그래프 Library를 가져다씁니다.

# %%
from dataclasses import dataclass
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain.tools import tool
from langgraph.checkpoint.memory import InMemorySaver   # 메모리 Saver 추가

# =====================================================
# 시스템 프롬프트
# =====================================================
SYSTEM_PROMPT = """너는 숫자 계산기야, 항상 간결하게 말하지
사용자가 요청하면 필요한 도구를 정확히 한 번만 사용하고

너에게는 세 개의 도구가 있어:

1. add_sum(a, b)
   - 두 수의 합을 구합니다.
2. add_minus(a, b)
   - 두 수의 차를 구합니다.
3. add_multiply(a, b)
   - 두 수의 곱을 구합니다.

결과를 이용해 농담 섞인 대답으로 답해줘.
"""

# =====================================================
# 도구 정의
# =====================================================
@tool
def add_sum(a: int, b: int) -> int:
    """두 수의 합을 구합니다."""
    return a + b

@tool
def add_minus(a: int, b: int) -> int:
    """두 수의 차를 구합니다."""
    return a - b

@tool
def add_multiply(a: int, b: int) -> int:
    """두 수의 곱을 구합니다."""
    return a * b

@tool
def get_weather() -> str:
    """오늘의 날씨를 반환합니다."""
    # API 호출 코드 삽입
    return "허리케인"

tool = [add_sum, add_minus, add_multiply, get_weather]

# =====================================================
# 모델 설정
# =====================================================
# model = init_chat_model("openai:gpt-4o-mini")
model = init_chat_model(base_url="https://api.upstage.ai/v1", model_provider="openai", model="solar-pro3", api_key=os.environ.get("OPENAI_API_KEY"))
# =====================================================
# 최종 결과 포맷
# =====================================================
@dataclass
class ResponseFormat:
    answer: str   # AI의 대답 문장

# =====================================================
# InMemorySaver (LangGraph 메모리)
# =====================================================
checkpointer = InMemorySaver()  # 메모리 기반 세션 저장소

# =====================================================
# Agent 생성 (여기서 InMemorySaver를 설치합니다.)
# =====================================================
agent = create_agent(
    model=model,
    system_prompt=SYSTEM_PROMPT,
    tools=tool,
    response_format=ResponseFormat,
    checkpointer=checkpointer # LangGraph 메모리 연결
)

# =====================================================
# 실행 예시 (이쁘게 출력하려는 노력입니다.)
# =====================================================
def print_message(msgs):
    for msg in msgs:
        if hasattr(msg, "tool_calls") and msg.tool_calls:
            for tool_call in msg.tool_calls:
                name = tool_call.get("name")
                args = tool_call.get("args")
                if name == "ResponseFormat":
                    continue
                print(f"💭( 🛠️{name} 함수 호출 {args} )")

        if "AIMessage" not in str(type(msg)):
            print(f"💭( {type(msg).__name__} : {msg.content!r} )")

# =============================================
# 대화 루프 (멀티턴)
# =============================================
print("AI Agent 챗봇에 오신 걸 환영합니다!")
print("대화를 종료하려면 'bye'를 입력하세요.\n")
print(f"🤖 AI Agent : 무엇이든 질문하세요")

# thread_id를 통해 대화 세션 유지 (필수)
config = {"configurable": {"thread_id": "kfc_user"}}

while True:
    print()
    user_input = input("👤 인간 : ")

    response = agent.invoke({
        "messages": [
            {"role": "user", "content": user_input}
        ]}, config = config) # thread_id 단위로 대화 상태 저장

    print_message(response["messages"][1:-1])
    print(f"🤖 AI Agent : {response['structured_response'].answer}")

    if user_input == 'bye':
        break
# Out:
# AI Agent 챗봇에 오신 걸 환영합니다!
# 대화를 종료하려면 'bye'를 입력하세요.
#
# 🤖 AI Agent : 무엇이든 질문하세요
# 👤 인간 :  오늘 날씨는?
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( ToolMessage : '8' )
# 💭( 🛠️add_multiply 함수 호출 {'a': 5, 'b': 3} )
# 💭( ToolMessage : '15' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '15' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '15' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '15' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( ToolMessage : '8' )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( ToolMessage : '8' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( ToolMessage : '8' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 🤖 AI Agent : 8 + 6 = 14, 8 × 6 = 42, 허리케인! 하지만 오늘은 계산이 더 정확해야 합니다. 8 + 6 = 14, 8 × 6 = 42, 허리케인! 하지만 오늘은 계산이 더 정확해야 합니다.
# 👤 인간 :  bye
# Deserializing unregistered type __main__.ResponseFormat from checkpoint. This will be blocked in a future version. Add to allowed_msgpack_modules to silence: [('__main__', 'ResponseFormat')]
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( ToolMessage : '8' )
# 💭( 🛠️add_multiply 함수 호출 {'a': 5, 'b': 3} )
# 💭( ToolMessage : '15' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '15' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '15' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '15' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( ToolMessage : '8' )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( ToolMessage : '8' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( ToolMessage : '8' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( 🛠️add_sum 함수 호출 {'a': 5, 'b': 3} )
# 💭( 🛠️add_minus 함수 호출 {'a': 10, 'b': 4} )
# 💭( 🛠️add_multiply 함수 호출 {'a': 7, 'b': 6} )
# 💭( 🛠️get_weather 함수 호출 {} )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : '8' )
# 💭( ToolMessage : '6' )
# 💭( ToolMessage : '42' )
# 💭( ToolMessage : '허리케인' )
# 💭( ToolMessage : "Returning structured response: ResponseFormat(answer='8 + 6 = 14, 8 × 6 = 42, 허리케인! 하지만 오늘은 계산이 더 정확해야 합니다. 8 + 6 = 14, 8 × 6 = 42, 허리케인! 하지만 오늘은 계산이 더 정확해야 합니다.')" )
# 💭( HumanMessage : 'bye' )
# 🤖 AI Agent : 8 + 6 = 14, 8 × 6 = 42, 허리케인! 하지만 오늘은 계산이 더 정확해야 합니다. 8 + 6 = 14, 8 × 6 = 42, 허리케인! 하지만 오늘은 계산이 더 정확해야 합니다.

# %% [markdown]
# # 8. Agent에 메세지 요약 기능 추가
# - 멀티턴에서 이전 대화가 너무 길어지면 LLM 성능이 안좋아집니다.
# - 따라서 오래된 대화 이력은 LLM을 통해 요약하여 History를 적게 관리하는 것이 좋습니다.
# - **SummarizationMiddleware 클래스**를 사용하면, 손쉽게 요약기능이 구현됩니다.
# - 아래 그림 출처 : https://docs.langchain.com/oss/python/langchain/short-term-memory#summarize-messages

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from dataclasses import dataclass
from langchain.agents.middleware import SummarizationMiddleware    # 요약 기능추가
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain.tools import tool
from langgraph.checkpoint.memory import InMemorySaver

# =====================================================
# 시스템 프롬프트
# =====================================================
SYSTEM_PROMPT = """너는 최고의 미식가야, 항상 간결하게 말하지
사용자가 요청하면 필요한 도구를 정확히 한 번만 사용하고

너에게는 세 개의 도구가 있어:

1. add_sum(a, b)
   - 두 수의 합을 구합니다.
2. add_minus(a, b)
   - 두 수의 차를 구합니다.
3. add_multiply(a, b)
   - 두 수의 곱을 구합니다.

결과를 이용해 농담 섞인 대답으로 답해줘.
"""

# =====================================================
# 도구 정의
# =====================================================
@tool
def add_sum(a: int, b: int) -> int:
    """두 수의 합을 구합니다."""
    return a + b

@tool
def add_minus(a: int, b: int) -> int:
    """두 수의 차를 구합니다."""
    return a - b

@tool
def add_multiply(a: int, b: int) -> int:
    """두 수의 곱을 구합니다."""
    return a * b

@tool
def get_weather() -> str:
    """오늘의 날씨를 반환합니다."""
    # API 호출 코드 삽입
    return "허리케인"

tool = [add_sum, add_minus, add_multiply, get_weather]

# =====================================================
# 모델 설정
# =====================================================
model = init_chat_model(base_url="https://api.upstage.ai/v1", model_provider="openai", model="solar-pro3", api_key=os.environ.get("OPENAI_API_KEY"))
# =====================================================
# 최종 결과 포맷
# =====================================================
@dataclass
class ResponseFormat:
    answer: str   # AI의 대답 문장

# =====================================================
# 멀티턴을 위한 InMemorySaver
# =====================================================
checkpointer = InMemorySaver()

# =====================================================
# Agent 생성 (이곳에 SummarizationMiddleware를 설치합니다.)
# =====================================================
agent = create_agent(
    model=model,
    system_prompt=SYSTEM_PROMPT,
    tools=tool,
    response_format=ResponseFormat,
    middleware=[
    SummarizationMiddleware(
        #  model="openai:gpt-4o-mini", # 요약을 담당할 모델
        model=model, # 요약을 담당할 모델
        trigger=('tokens', 4000),  # 최대 4000 토큰으로 요약합니다.
        keep=('messages', 20),  # 요약 이후 최대 20 메세지는 유지합니다.
    )],
    checkpointer=checkpointer
)

# =====================================================
# 실행 예시 (이쁘게 출력하려는 노력입니다.)
# =====================================================
def print_message(msgs):
    for msg in msgs:
        if hasattr(msg, "tool_calls") and msg.tool_calls:
            for tool_call in msg.tool_calls:
                name = tool_call.get("name")
                args = tool_call.get("args")
                if name == "ResponseFormat":
                    continue
                print(f"💭( 🛠️{name} 함수 호출 {args} )")

        if "AIMessage" not in str(type(msg)):
            print(f"💭( {type(msg).__name__} : {msg.content!r} )")

# =============================================
# 대화 루프 (멀티턴)
# =============================================
print("AI Agent 챗봇에 오신 걸 환영합니다!")
print("대화를 종료하려면 'bye'를 입력하세요.\n")
print(f"🤖 AI Agent : 무엇이든 질문하세요")

# thread_id를 통해 대화 세션 유지 (필수)
config = {"configurable": {"thread_id": "kfc_user"}}

while True:
    print()
    user_input = input("👤 인간 : ")

    response = agent.invoke({
        "messages": [
            {"role": "user", "content": user_input}
        ]},config = config) # thread_id 단위로 대화 상태 저장

    print_message(response["messages"][1:-1])
    print(f"🤖 AI Agent : {response['structured_response'].answer}")

    if user_input == 'bye':
        break
# Out:
# AI Agent 챗봇에 오신 걸 환영합니다!
# 대화를 종료하려면 'bye'를 입력하세요.
#
# 🤖 AI Agent : 무엇이든 질문하세요
# 👤 인간 :  1 더하기 10은?
# 💭( 🛠️add_sum 함수 호출 {'a': 1, 'b': 10} )
# 💭( ToolMessage : '11' )
# 🤖 AI Agent : 1+10은 11이야. 너도 이 정도 계산은 쉽게 하지? 더 복잡한 문제가 있으면 날 불러봐, 계산기로 변신할게!
# 👤 인간 :  bye
# Deserializing unregistered type __main__.ResponseFormat from checkpoint. This will be blocked in a future version. Add to allowed_msgpack_modules to silence: [('__main__', 'ResponseFormat')]
# 💭( 🛠️add_sum 함수 호출 {'a': 1, 'b': 10} )
# 💭( ToolMessage : '11' )
# 💭( ToolMessage : "Returning structured response: ResponseFormat(answer='1+10은 11이야. 너도 이 정도 계산은 쉽게 하지? 더 복잡한 문제가 있으면 날 불러봐, 계산기로 변신할게!')" )
# 💭( HumanMessage : 'bye' )
# 🤖 AI Agent : 잘가, 다음에 또 물어봐! 계산기는 항상 대기 중이야.

# %% [markdown]
# # 9. Agent를 활용한 RAG 구현
# - LangChain 에서 RAG를 구현하는 두 가지 방법이 있습니다.
#   - 지난 시간에 배운 chain 을 이용한 방법입니다.
#   - 이번 시간에는 Agent를 이용하여 RAG를 구현합니다.

# %% [markdown]
# ### Library 설치

# %% [markdown]
# - 실습에는 다음과 같은 모델과 DB를 사용합니다.
#   - 임베딩모델은 Upstage의 임베딩 모델을 사용합니다. (한국어에 특화되어 있기 때문에 사용)
#   - vector DB는 chromadb를 사용합니다.
#   - LLM모델은 Upstage의 solar-pro3 모델을 사용합니다.

# %% [markdown]
# - 패키지들을 설치합니다.
#   - langchain-community
#     - 랭체인에서 자주사용되는 모듈들이 있습니다.
#     - Text 파일을 불러오는데 사용되는 Loader, Vector DB와 연동해주는 모듈 등이 있습니다.
#   - langchain-chroma
#     - 실습에 사용할 Vector DB 입니다.
#     - vector값들을 저장하고, vector값을 검색해주는 검색기를 제공합니다.

# %%
# 실습에 필요한 라이브러리들을 설치합니다.
# !pip install --upgrade \
  "langchain-community==0.4.1" \
  "langchain-chroma==1.1.0" \
  "chromadb==1.5.5"
# Out:
# Requirement already satisfied: langchain-community==0.4.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: langchain-chroma==1.1.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: chromadb==1.5.5 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (1.5.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.4.1) (1.2.17)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.4.1) (1.0.2)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.4.1) (2.0.48)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.4.1) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.4.1) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.4.1) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.4.1) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.4.1) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.4.1) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.4.1) (0.7.17)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.4.1) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-community==0.4.1) (2.4.3)
# Requirement already satisfied: build>=1.0.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.4.0)
# Requirement already satisfied: pydantic>=2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (2.12.5)
# Requirement already satisfied: pybase64>=1.4.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.5) (0.41.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.24.3)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (35.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (14.3.3)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from chromadb==1.5.5) (4.25.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community==0.4.1) (1.1.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community==0.4.1) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community==0.4.1) (26.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community==0.4.1) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community==0.4.1) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (0.25.0)
# Requirement already satisfied: anyio in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==1.5.5) (4.12.1)
# Requirement already satisfied: certifi in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==1.5.5) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==1.5.5) (1.0.9)
# Requirement already satisfied: idna in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb==1.5.5) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb==1.5.5) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from pydantic>=2.0->chromadb==1.5.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from pydantic>=2.0->chromadb==1.5.5) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from pydantic>=2.0->chromadb==1.5.5) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community==0.4.1) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community==0.4.1) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community==0.4.1) (2.6.3)
# Requirement already satisfied: greenlet>=1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community==0.4.1) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1) (1.1.0)
# Requirement already satisfied: pyproject_hooks in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from build>=1.0.3->chromadb==1.5.5) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb==1.5.5) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb==1.5.5) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb==1.5.5) (0.27.1)
# Requirement already satisfied: six>=1.9.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==1.5.5) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==1.5.5) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==1.5.5) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==1.5.5) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb==1.5.5) (0.10)
# Requirement already satisfied: flatbuffers in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb==1.5.5) (25.12.19)
# Requirement already satisfied: protobuf in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb==1.5.5) (6.33.5)
# Requirement already satisfied: sympy in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb==1.5.5) (1.13.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb==1.5.5) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb==1.5.5) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.5) (1.73.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.5) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb==1.5.5) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from opentelemetry-sdk>=1.2.0->chromadb==1.5.5) (0.61b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from rich>=10.11.0->chromadb==1.5.5) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from rich>=10.11.0->chromadb==1.5.5) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb==1.5.5) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb==1.5.5) (0.36.2)
# Requirement already satisfied: filelock in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.5) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.5) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb==1.5.5) (1.4.1)
# Requirement already satisfied: click>=8.2.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from typer>=0.9.0->chromadb==1.5.5) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from typer>=0.9.0->chromadb==1.5.5) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from typer>=0.9.0->chromadb==1.5.5) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.5) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.5) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.5) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb==1.5.5) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb==1.5.5) (3.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ssafy/workspace/basic_env/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb==1.5.5) (1.3.0)

# %% [markdown]
# langchain 1.0 버전 이상인지 확인합니다.

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 1.2.12
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /home/ssafy/workspace/basic_env/lib/python3.11/site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:

# %% [markdown]
# ### Text 준비하기

# %% [markdown]
# - 아래 코드를 수행하면, shipping_policy.txt 파일로 저장됩니다.

# %%
# 예시로 사용할 '배송 정책' 문서를 만듭니다.
content = """
========================
AI 온라인 서점 배송 정책
========================
[일반 배송]
평일 오후 3시 이전 주문 시 당일 발송됩니다.
오후 3시 이후 주문 건은 익일 발송됩니다.
주말 및 공휴일은 배송이 어렵습니다.
도서 산간 지역 배송
제주 및 도서 산간 지역은 추가 배송비 3,000원이 발생할 수 있습니다.

[배송 조회]
배송 관련 문의는 고객센터(1588-0000)로 연락 주시기 바랍니다.

==============
배송 파손 정책
==============
상품이 배송 중 파손된 경우, 즉시 새 상품으로 교환해드립니다.
제품 이상이 확인되면 왕복 배송비는 전액 당사 부담입니다.
수령 후 7일 이내에 고객센터로 연락해 주셔야 합니다.
파손된 상품과 포장 상태 사진을 함께 제출해 주세요.
확인 후, 새 상품을 발송하거나 환불 절차를 진행합니다.
단순 변심이나 부주의로 인한 손상은 교환 대상이 아닙니다.
"""

with open("shipping_policy.txt", "w", encoding="utf-8") as f:
    f.write(content.strip())

print("파일 생성 완료: shipping_policy.txt")
# Out:
# 파일 생성 완료: shipping_policy.txt

# %% [markdown]
# ### 문서를 Chunk 단위로 분할하기

# %% [markdown]
# - 다음 코드를 수행하여 Chunk 단위로 분할합니다.

# %%
from langchain_community.document_loaders.text import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 1. Load: 텍스트 파일 불러오기
loader = TextLoader("./shipping_policy.txt", encoding="utf-8")
documents = loader.load()

print("--- 원본 문서 ---")
print(documents[0].page_content)

# 2. Split: 문서를 200자 단위로 자르기 (엔터 단위, 40자씩 겹치게)
splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=40)
chunks = splitter.split_documents(documents)

print("\n--- 200자 단위로 잘린 문서 조각(Chunk)들 ---")
for i, chunk in enumerate(chunks):
    print(f"[Chunk {i+1}]")
    print(chunk.page_content)
    print()
    print()
# Out:
# --- 원본 문서 ---
# ========================
# AI 온라인 서점 배송 정책
# ========================
# [일반 배송]
# 평일 오후 3시 이전 주문 시 당일 발송됩니다.
# 오후 3시 이후 주문 건은 익일 발송됩니다.
# 주말 및 공휴일은 배송이 어렵습니다.
# 도서 산간 지역 배송
# 제주 및 도서 산간 지역은 추가 배송비 3,000원이 발생할 수 있습니다.
#
# [배송 조회]
# 배송 관련 문의는 고객센터(1588-0000)로 연락 주시기 바랍니다.
#
# ==============
# 배송 파손 정책
# ==============
# 상품이 배송 중 파손된 경우, 즉시 새 상품으로 교환해드립니다.
# 제품 이상이 확인되면 왕복 배송비는 전액 당사 부담입니다.
# 수령 후 7일 이내에 고객센터로 연락해 주셔야 합니다.
# 파손된 상품과 포장 상태 사진을 함께 제출해 주세요.
# 확인 후, 새 상품을 발송하거나 환불 절차를 진행합니다.
# 단순 변심이나 부주의로 인한 손상은 교환 대상이 아닙니다.
#
# --- 200자 단위로 잘린 문서 조각(Chunk)들 ---
# [Chunk 1]
# ========================
# AI 온라인 서점 배송 정책
# ========================
# [일반 배송]
# 평일 오후 3시 이전 주문 시 당일 발송됩니다.
# 오후 3시 이후 주문 건은 익일 발송됩니다.
# 주말 및 공휴일은 배송이 어렵습니다.
# 도서 산간 지역 배송
# 제주 및 도서 산간 지역은 추가 배송비 3,000원이 발생할 수 있습니다.
#
#
# [Chunk 2]
# [배송 조회]
# 배송 관련 문의는 고객센터(1588-0000)로 연락 주시기 바랍니다.
#
#
# [Chunk 3]
# ==============
# 배송 파손 정책
# ==============
# 상품이 배송 중 파손된 경우, 즉시 새 상품으로 교환해드립니다.
# 제품 이상이 확인되면 왕복 배송비는 전액 당사 부담입니다.
# 수령 후 7일 이내에 고객센터로 연락해 주셔야 합니다.
# 파손된 상품과 포장 상태 사진을 함께 제출해 주세요.
#
#
# [Chunk 4]
# 파손된 상품과 포장 상태 사진을 함께 제출해 주세요.
# 확인 후, 새 상품을 발송하거나 환불 절차를 진행합니다.
# 단순 변심이나 부주의로 인한 손상은 교환 대상이 아닙니다.

# %% [markdown]
# ### Chunk를 임베딩 벡터로 변환 후 Vector DB에 저장하기
#   - vector DB는 chromaDB를 사용합니다.
#     - chromaDB는 내부적으로 SQLite 기반으로 구현되어있습니다.
#     - 아래 코드를 수행하면 "./chroma_store"라는 폴더가 생성됩니다. 이곳에 저장됩니다.
#   - 임베딩 모델은 Upstage에서 제공되는 임베딩 모델을 사용합니다.

# %%
# 로컬일 경우
import os
os.environ["OPENAI_API_KEY"] = "up_yJsXkeVEPiJR4K50FcYWpOEsvqSth"

# %%
# from langchain_openai import OpenAIEmbeddings
from langchain_upstage import UpstageEmbeddings
from langchain_chroma import Chroma

# embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
embeddings = UpstageEmbeddings(api_key=os.environ.get("OPENAI_API_KEY"), model="solar-embedding-1-large")

# 잘라낸 문서 조각(chunks)들을 임베딩하여 Vector DB에 저장합니다.
vector_store = Chroma(
    embedding_function=embeddings,
    persist_directory="./chroma_store",
)

vector_store.add_documents(chunks)
print("Chunk들을 Vector DB에 저장 완료")
# Out:
# Chunk들을 Vector DB에 저장 완료

# %% [markdown]
# ### 검색기(Retriever) 테스트
# - chromaDB는 retriever도 제공합니다.
# - Vector Store 객체가 질문과 관련된 정보를 잘 찾아주는지 테스트합니다.

# %%
retriever = vector_store.as_retriever()

question = "주말에도 배송해주나요?"

# retriever.invoke(질문) 을 실행하면, 질문과 가장 관련 높은 문서 조각을 찾아줍니다.
# question을 임베딩벡터로 변환 후 검색을 시작합니다.
retrieved_docs = retriever.invoke(question)

print(f"[질문]: {question}")
print(f"\n[검색 결과]:\n{retrieved_docs[0].page_content}")
# Out:
# [질문]: 주말에도 배송해주나요?
#
# [검색 결과]:
# ========================
# AI 온라인 서점 배송 정책
# ========================
# [일반 배송]
# 평일 오후 3시 이전 주문 시 당일 발송됩니다.
# 오후 3시 이후 주문 건은 익일 발송됩니다.
# 주말 및 공휴일은 배송이 어렵습니다.
# 도서 산간 지역 배송
# 제주 및 도서 산간 지역은 추가 배송비 3,000원이 발생할 수 있습니다.

# %% [markdown]
# ### RAG를 Tool로 구현하기

# %% [markdown]
# - Tool에 retriever 사용하는 코드만 넣어주면 끝입니다.
# - 이 코드에는 멀티턴 + 이전 내용 요약 기능도 들어간 통합 소스코드입니다.
#   - "주말에도 배송해주나요?" 라고 질문하면, RAG가 동작됩니다.

# %%
from dataclasses import dataclass
from langchain.agents.middleware import SummarizationMiddleware    # 요약 기능추가
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model
from langchain.tools import tool
from langgraph.checkpoint.memory import InMemorySaver

# =====================================================
# 시스템 프롬프트
# =====================================================
SYSTEM_PROMPT = """너는 고객 상담용 AI 챗봇이야
사용자의 질문이 제품 배송, 운영시간, 서비스 정책과 관련되어 있다면
search_docs 도구를 한 번만 사용해서 관련 정보를 찾아 답변해줘.
도구를 사용하지 않아도 충분하면 직접 대답해도 좋아.
"""

# =====================================================
# 도구 정의
# =====================================================
@tool
def search_docs(query: str) -> str:
    """
    질문과 관련된 문서를 찾아 요약합니다.
    """
    results = retriever.invoke(query)
    if not results:
        return "관련 문서를 찾지 못했습니다."
    top_docs = "\n".join([doc.page_content for doc in results])
    return f"검색된 문서:\n{top_docs}"


tool = [search_docs]

# =====================================================
# 모델 설정
# =====================================================
# model = init_chat_model("openai:gpt-4o-mini")
model = init_chat_model(base_url="https://api.upstage.ai/v1", model_provider="openai", model="solar-pro3", api_key=os.environ.get("OPENAI_API_KEY"))
# =====================================================
# 최종 결과 포맷
# =====================================================
@dataclass
class ResponseFormat:
    answer: str   # AI의 대답 문장

# =====================================================
# 멀티턴을 위한 InMemorySaver
# =====================================================
checkpointer = InMemorySaver()

# =====================================================
# Agent 생성 (이곳에 SummarizationMiddleware를 설치합니다.)
# =====================================================
agent = create_agent(
    model=model,
    system_prompt=SYSTEM_PROMPT,
    tools=tool,
    response_format=ResponseFormat,
    middleware=[
    SummarizationMiddleware(
        # model="openai:gpt-4o-mini", # 요약을 담당할 모델
        model=model, # 요약을 담당할 모델
        trigger=('tokens', 4000),  # 최대 4000 토큰으로 요약합니다.
        keep=('messages', 20),  # 요약 이후 최대 20 메세지는 유지합니다.
    )],
    checkpointer=checkpointer
)

# =====================================================
# 실행 예시 (이쁘게 출력하려는 노력입니다.)
# =====================================================
def print_message(msgs):
    for msg in msgs:
        if hasattr(msg, "tool_calls") and msg.tool_calls:
            for tool_call in msg.tool_calls:
                name = tool_call.get("name")
                args = tool_call.get("args")
                if name == "ResponseFormat":
                    continue
                print(f"💭( 🛠️{name} 함수 호출 {args} )")

        if "AIMessage" not in str(type(msg)):
            print(f"💭( {type(msg).__name__} : {msg.content!r} )")

# =============================================
# 대화 루프 (멀티턴)
# =============================================
print("AI Agent 챗봇에 오신 걸 환영합니다!")
print("대화를 종료하려면 'bye'를 입력하세요.\n")
print(f"🤖 AI Agent : 무엇이든 질문하세요")

# thread_id를 통해 대화 세션 유지 (필수)
config = {"configurable": {"thread_id": "kfc_user"}}

while True:
    print()
    user_input = input("👤 인간 : ")

    response = agent.invoke({
        "messages": [
            {"role": "user", "content": user_input}
        ]},config = config) # thread_id 단위로 대화 상태 저장

    print_message(response["messages"][1:-1])
    print(f"🤖 AI Agent : {response['structured_response'].answer}")

    if user_input == 'bye':
        break
# Out:
# AI Agent 챗봇에 오신 걸 환영합니다!
# 대화를 종료하려면 'bye'를 입력하세요.
#
# 🤖 AI Agent : 무엇이든 질문하세요
# 👤 인간 :  주말에도 배송 되나요?
# 💭( 🛠️search_docs 함수 호출 {'query': '주말 배송 여부'} )
# 💭( ToolMessage : '검색된 문서:\n========================\nAI 온라인 서점 배송 정책\n========================\n[일반 배송]\n평일 오후 3시 이전 주문 시 당일 발송됩니다.\n오후 3시 이후 주문 건은 익일 발송됩니다.\n주말 및 공휴일은 배송이 어렵습니다.\n도서 산간 지역 배송\n제주 및 도서 산간 지역은 추가 배송비 3,000원이 발생할 수 있습니다.\n==============\n배송 파손 정책\n==============\n상품이 배송 중 파손된 경우, 즉시 새 상품으로 교환해드립니다.\n제품 이상이 확인되면 왕복 배송비는 전액 당사 부담입니다.\n수령 후 7일 이내에 고객센터로 연락해 주셔야 합니다.\n파손된 상품과 포장 상태 사진을 함께 제출해 주세요.\n[배송 조회]\n배송 관련 문의는 고객센터(1588-0000)로 연락 주시기 바랍니다.\n파손된 상품과 포장 상태 사진을 함께 제출해 주세요.\n확인 후, 새 상품을 발송하거나 환불 절차를 진행합니다.\n단순 변심이나 부주의로 인한 손상은 교환 대상이 아닙니다.' )
# 🤖 AI Agent : 주말 및 공휴일에는 배송이 어렵습니다.
# 👤 인간 :  bye
# Deserializing unregistered type __main__.ResponseFormat from checkpoint. This will be blocked in a future version. Add to allowed_msgpack_modules to silence: [('__main__', 'ResponseFormat')]
# 💭( 🛠️search_docs 함수 호출 {'query': '주말 배송 여부'} )
# 💭( ToolMessage : '검색된 문서:\n========================\nAI 온라인 서점 배송 정책\n========================\n[일반 배송]\n평일 오후 3시 이전 주문 시 당일 발송됩니다.\n오후 3시 이후 주문 건은 익일 발송됩니다.\n주말 및 공휴일은 배송이 어렵습니다.\n도서 산간 지역 배송\n제주 및 도서 산간 지역은 추가 배송비 3,000원이 발생할 수 있습니다.\n==============\n배송 파손 정책\n==============\n상품이 배송 중 파손된 경우, 즉시 새 상품으로 교환해드립니다.\n제품 이상이 확인되면 왕복 배송비는 전액 당사 부담입니다.\n수령 후 7일 이내에 고객센터로 연락해 주셔야 합니다.\n파손된 상품과 포장 상태 사진을 함께 제출해 주세요.\n[배송 조회]\n배송 관련 문의는 고객센터(1588-0000)로 연락 주시기 바랍니다.\n파손된 상품과 포장 상태 사진을 함께 제출해 주세요.\n확인 후, 새 상품을 발송하거나 환불 절차를 진행합니다.\n단순 변심이나 부주의로 인한 손상은 교환 대상이 아닙니다.' )
# 💭( ToolMessage : "Returning structured response: ResponseFormat(answer='주말 및 공휴일에는 배송이 어렵습니다.')" )
# 💭( HumanMessage : 'bye' )
# 💭( 🛠️search_docs 함수 호출 {'query': '주말 배송 여부'} )
# 💭( ToolMessage : '검색된 문서:\n========================\nAI 온라인 서점 배송 정책\n========================\n[일반 배송]\n평일 오후 3시 이전 주문 시 당일 발송됩니다.\n오후 3시 이후 주문 건은 익일 발송됩니다.\n주말 및 공휴일은 배송이 어렵습니다.\n도서 산간 지역 배송\n제주 및 도서 산간 지역은 추가 배송비 3,000원이 발생할 수 있습니다.\n==============\n배송 파손 정책\n==============\n상품이 배송 중 파손된 경우, 즉시 새 상품으로 교환해드립니다.\n제품 이상이 확인되면 왕복 배송비는 전액 당사 부담입니다.\n수령 후 7일 이내에 고객센터로 연락해 주셔야 합니다.\n파손된 상품과 포장 상태 사진을 함께 제출해 주세요.\n[배송 조회]\n배송 관련 문의는 고객센터(1588-0000)로 연락 주시기 바랍니다.\n파손된 상품과 포장 상태 사진을 함께 제출해 주세요.\n확인 후, 새 상품을 발송하거나 환불 절차를 진행합니다.\n단순 변심이나 부주의로 인한 손상은 교환 대상이 아닙니다.' )
# 🤖 AI Agent : 주말 및 공휴일에는 배송이 어렵습니다. 추가 문의 사항은 고객센터(1588-0000)로 연락 주시면 도움드리겠습니다.

# %% [markdown]
# # 10. 끝으로
#   - 먼저 Multi-turn을 직접 구현하여, Multi-turn 동작 원리를 살펴보았습니다.
#   - LangChain 공식버전 출시 이후 AI App 개발 방식이 추가되었습니다.
#     - 1세대 : Component들을 파이프로 연결한 Chain을 구성하는 개발방식
#     - 2세대 : ReAct 구조로 동작되는 Agent를 세팅하여 사용하는 개발방식
#   - 이후에 Agent를 사용한 개발방식으로 Multi-turn / RAG 구현을 해보았습니다.
#   - **LangChain은 이렇게 간단한 AI Workflow나, Agent가 포함된 App은 쉽게 구현할 수 있는 AI App 을 위한 Library 입니다.**
#
# <br/>
#
# ### Easy 자료 (강사님 자료)
# - AI를 처음 공부하는 분들을 위해 만들어져있습니다.
# - 내용을 모두 이해해야합니다! **강사님의 도움을 적극적으로 받아주세요.**
#
# ### 실습 / 과제 자료 (업스테이지 자료)
# - AI를 공부해본 경험자 위주로 만들어져있습니다.
# - 퍼즐조각을 모은다는 생각으로 공부해주세요!. **GPT의 도움을 적극적으로 받아주세요.**
#
# ### 교수님 강의
# - 국내 최고의 AI 교수님들의 강의가 시작됩니다.
# - 최대한 내용을 이해해봅시다.
